# %%
import os
import shutil

# Ruta donde se encuentran todos los archivos
source_dir = './Dataset_500_EMPRESAS_v2'  # Cambia esto si es necesario

# Obtener todos los archivos en el directorio
files = os.listdir(source_dir)

# Crear un conjunto de todos los tickers únicos
tickers = set()
for file in files:
    if file.endswith('.csv') or file.endswith('.json'):
        parts = file.split('_')
        if len(parts) >= 2:
            ticker = parts[0]
            tickers.add(ticker)

# Crear carpetas y mover archivos
for ticker in tickers:
    folder_path = os.path.join(source_dir, ticker)
    if not os.path.exists(folder_path):
        os.makedirs(folder_path)
    
    for file in files:
        if file.startswith(ticker + '_'):
            source_file = os.path.join(source_dir, file)
            dest_file = os.path.join(folder_path, file)
            shutil.move(source_file, dest_file)
            print(f"Moved {file} to {folder_path}")

print("Organización completada.")
# Out:
# Moved FICO_completo.csv to ./Dataset_500_EMPRESAS_v2/FICO
# Moved IQV_completo.csv to ./Dataset_500_EMPRESAS_v2/IQV
# Moved PWR_completo.csv to ./Dataset_500_EMPRESAS_v2/PWR
# Moved NFLX_completo.csv to ./Dataset_500_EMPRESAS_v2/NFLX
# Moved DVN_completo.csv to ./Dataset_500_EMPRESAS_v2/DVN
# Moved SHW_completo.csv to ./Dataset_500_EMPRESAS_v2/SHW
# Moved LOW_completo.csv to ./Dataset_500_EMPRESAS_v2/LOW
# Moved ACGL_completo.csv to ./Dataset_500_EMPRESAS_v2/ACGL
# Moved HWM_completo.csv to ./Dataset_500_EMPRESAS_v2/HWM
# Moved PYPL_completo.csv to ./Dataset_500_EMPRESAS_v2/PYPL
# Moved ITW_completo.csv to ./Dataset_500_EMPRESAS_v2/ITW
# Moved LYB_completo.csv to ./Dataset_500_EMPRESAS_v2/LYB
# Moved TKO_completo.csv to ./Dataset_500_EMPRESAS_v2/TKO
# Moved AFL_completo.csv to ./Dataset_500_EMPRESAS_v2/AFL
# Moved BMY_completo.csv to ./Dataset_500_EMPRESAS_v2/BMY
# Moved EXPD_completo.csv to ./Dataset_500_EMPRESAS_v2/EXPD
# Moved RMD_completo.csv to ./Dataset_500_EMPRESAS_v2/RMD
# Moved HBAN_completo.csv to ./Dataset_500_EMPRESAS_v2/HBAN
# Moved ES_completo.csv to ./Dataset_500_EMPRESAS_v2/ES
# Moved MCHP_completo.csv to ./Dataset_500_EMPRESAS_v2/MCHP
# Moved BXP_completo.csv to ./Dataset_500_EMPRESAS_v2/BXP
# Moved TGT_completo.csv to ./Dataset_500_EMPRESAS_v2/TGT
# Moved CNP_completo.csv to ./Dataset_500_EMPRESAS_v2/CNP
# Moved TEL_completo.csv to ./Dataset_500_EMPRESAS_v2/TEL
# Moved O_completo.csv to ./Dataset_500_EMPRESAS_v2/O
# Moved EXR_completo.csv to ./Dataset_500_EMPRESAS_v2/EXR
# Moved DTE_completo.csv to ./Dataset_500_EMPRESAS_v2/DTE
# Moved ECL_completo.csv to ./Dataset_500_EMPRESAS_v2/ECL
# Moved ROST_completo.csv to ./Dataset_500_EMPRESAS_v2/ROST
# Moved PG_completo.csv to ./Dataset_500_EMPRESAS_v2/PG
# Moved LVS_completo.csv to ./Dataset_500_EMPRESAS_v2/LVS
# Moved WST_completo.csv to ./Dataset_500_EMPRESAS_v2/WST
# Moved PCAR_completo.csv to ./Dataset_500_EMPRESAS_v2/PCAR
# Moved ANET_completo.csv to ./Dataset_500_EMPRESAS_v2/ANET
# Moved CMG_completo.csv to ./Dataset_500_EMPRESAS_v2/CMG
# Moved LLY_completo.csv to ./Dataset_500_EMPRESAS_v2/LLY
# Moved ODFL_completo.csv to ./Dataset_500_EMPRESAS_v2/ODFL
# Moved HLT_completo.csv to ./Dataset_500_EMPRESAS_v2/HLT
# Moved UHS_completo.csv to ./Dataset_500_EMPRESAS_v2/UHS
# Moved CNC_completo.csv to ./Dataset_500_EMPRESAS_v2/CNC
# Moved DOW_completo.csv to ./Dataset_500_EMPRESAS_v2/DOW
# Moved CTVA_completo.csv to ./Dataset_500_EMPRESAS_v2/CTVA
# Moved VTR_completo.csv to ./Dataset_500_EMPRESAS_v2/VTR
# Moved KLAC_completo.csv to ./Dataset_500_EMPRESAS_v2/KLAC
# Moved INTU_completo.csv to ./Dataset_500_EMPRESAS_v2/INTU
# Moved BLK_completo.csv to ./Dataset_500_EMPRESAS_v2/BLK
# Moved PH_completo.csv to ./Dataset_500_EMPRESAS_v2/PH
# Moved FITB_completo.csv to ./Dataset_500_EMPRESAS_v2/FITB
# Moved JPM_completo.csv to ./Dataset_500_EMPRESAS_v2/JPM
# Moved TXN_completo.csv to ./Dataset_500_EMPRESAS_v2/TXN
# Moved RL_completo.csv to ./Dataset_500_EMPRESAS_v2/RL
# Moved COIN_completo.csv to ./Dataset_500_EMPRESAS_v2/COIN
# Moved YUM_completo.csv to ./Dataset_500_EMPRESAS_v2/YUM
# Moved JBHT_completo.csv to ./Dataset_500_EMPRESAS_v2/JBHT
# Moved TDY_completo.csv to ./Dataset_500_EMPRESAS_v2/TDY
# Moved FRT_completo.csv to ./Dataset_500_EMPRESAS_v2/FRT
# Moved FIS_completo.csv to ./Dataset_500_EMPRESAS_v2/FIS
# Moved AMCR_completo.csv to ./Dataset_500_EMPRESAS_v2/AMCR
# Moved PFG_completo.csv to ./Dataset_500_EMPRESAS_v2/PFG
# Moved SO_completo.csv to ./Dataset_500_EMPRESAS_v2/SO
# Moved KEY_completo.csv to ./Dataset_500_EMPRESAS_v2/KEY
# Moved SNPS_completo.csv to ./Dataset_500_EMPRESAS_v2/SNPS
# Moved DPZ_completo.csv to ./Dataset_500_EMPRESAS_v2/DPZ
# Moved GPN_completo.csv to ./Dataset_500_EMPRESAS_v2/GPN
# Moved CTAS_completo.csv to ./Dataset_500_EMPRESAS_v2/CTAS
# Moved SPG_completo.csv to ./Dataset_500_EMPRESAS_v2/SPG
# Moved WBD_completo.csv to ./Dataset_500_EMPRESAS_v2/WBD
# Moved TROW_completo.csv to ./Dataset_500_EMPRESAS_v2/TROW
# Moved MU_completo.csv to ./Dataset_500_EMPRESAS_v2/MU
# Moved ORLY_completo.csv to ./Dataset_500_EMPRESAS_v2/ORLY
# Moved QCOM_completo.csv to ./Dataset_500_EMPRESAS_v2/QCOM
# Moved OKE_completo.csv to ./Dataset_500_EMPRESAS_v2/OKE
# Moved INTC_completo.csv to ./Dataset_500_EMPRESAS_v2/INTC
# Moved SCHW_completo.csv to ./Dataset_500_EMPRESAS_v2/SCHW
# Moved FFIV_completo.csv to ./Dataset_500_EMPRESAS_v2/FFIV
# Moved MSI_completo.csv to ./Dataset_500_EMPRESAS_v2/MSI
# Moved GOOG_completo.csv to ./Dataset_500_EMPRESAS_v2/GOOG
# Moved TXT_completo.csv to ./Dataset_500_EMPRESAS_v2/TXT
# Moved HPE_completo.csv to ./Dataset_500_EMPRESAS_v2/HPE
# Moved LDOS_completo.csv to ./Dataset_500_EMPRESAS_v2/LDOS
# Moved IFF_completo.csv to ./Dataset_500_EMPRESAS_v2/IFF
# Moved KHC_completo.csv to ./Dataset_500_EMPRESAS_v2/KHC
# Moved AMD_completo.csv to ./Dataset_500_EMPRESAS_v2/AMD
# Moved AMT_completo.csv to ./Dataset_500_EMPRESAS_v2/AMT
# Moved INVH_completo.csv to ./Dataset_500_EMPRESAS_v2/INVH
# Moved EQT_completo.csv to ./Dataset_500_EMPRESAS_v2/EQT
# Moved BRO_completo.csv to ./Dataset_500_EMPRESAS_v2/BRO
# Moved MPC_completo.csv to ./Dataset_500_EMPRESAS_v2/MPC
# Moved BALL_completo.csv to ./Dataset_500_EMPRESAS_v2/BALL
# Moved PEP_completo.csv to ./Dataset_500_EMPRESAS_v2/PEP
# Moved HII_completo.csv to ./Dataset_500_EMPRESAS_v2/HII
# Moved DRI_completo.csv to ./Dataset_500_EMPRESAS_v2/DRI
# Moved NTAP_completo.csv to ./Dataset_500_EMPRESAS_v2/NTAP
# Moved RJF_completo.csv to ./Dataset_500_EMPRESAS_v2/RJF
# Moved POOL_completo.csv to ./Dataset_500_EMPRESAS_v2/POOL
# Moved PSX_completo.csv to ./Dataset_500_EMPRESAS_v2/PSX
# Moved NRG_completo.csv to ./Dataset_500_EMPRESAS_v2/NRG
# Moved UNP_completo.csv to ./Dataset_500_EMPRESAS_v2/UNP
# Moved KMB_completo.csv to ./Dataset_500_EMPRESAS_v2/KMB
# Moved WDC_completo.csv to ./Dataset_500_EMPRESAS_v2/WDC
# Moved CRWD_completo.csv to ./Dataset_500_EMPRESAS_v2/CRWD
# Moved PARA_completo.csv to ./Dataset_500_EMPRESAS_v2/PARA
# Moved JBL_completo.csv to ./Dataset_500_EMPRESAS_v2/JBL
# Moved BX_completo.csv to ./Dataset_500_EMPRESAS_v2/BX
# Moved DOC_completo.csv to ./Dataset_500_EMPRESAS_v2/DOC
# Moved HD_completo.csv to ./Dataset_500_EMPRESAS_v2/HD
# Moved UNH_completo.csv to ./Dataset_500_EMPRESAS_v2/UNH
# Moved ADM_completo.csv to ./Dataset_500_EMPRESAS_v2/ADM
# Moved NWSA_completo.csv to ./Dataset_500_EMPRESAS_v2/NWSA
# Moved HON_completo.csv to ./Dataset_500_EMPRESAS_v2/HON
# Moved IDXX_completo.csv to ./Dataset_500_EMPRESAS_v2/IDXX
# Moved GLW_completo.csv to ./Dataset_500_EMPRESAS_v2/GLW
# Moved TAP_completo.csv to ./Dataset_500_EMPRESAS_v2/TAP
# Moved GEHC_completo.csv to ./Dataset_500_EMPRESAS_v2/GEHC
# Moved TJX_completo.csv to ./Dataset_500_EMPRESAS_v2/TJX
# Moved MOH_completo.csv to ./Dataset_500_EMPRESAS_v2/MOH
# Moved DLTR_completo.csv to ./Dataset_500_EMPRESAS_v2/DLTR
# Moved SJM_completo.csv to ./Dataset_500_EMPRESAS_v2/SJM
# Moved VZ_completo.csv to ./Dataset_500_EMPRESAS_v2/VZ
# Moved ETR_completo.csv to ./Dataset_500_EMPRESAS_v2/ETR
# Moved CBRE_completo.csv to ./Dataset_500_EMPRESAS_v2/CBRE
# Moved FOX_completo.csv to ./Dataset_500_EMPRESAS_v2/FOX
# Moved SNA_completo.csv to ./Dataset_500_EMPRESAS_v2/SNA
# Moved SWKS_completo.csv to ./Dataset_500_EMPRESAS_v2/SWKS
# Moved PLTR_completo.csv to ./Dataset_500_EMPRESAS_v2/PLTR
# Moved HOLX_completo.csv to ./Dataset_500_EMPRESAS_v2/HOLX
# Moved IR_completo.csv to ./Dataset_500_EMPRESAS_v2/IR
# Moved TDG_completo.csv to ./Dataset_500_EMPRESAS_v2/TDG
# Moved CLX_completo.csv to ./Dataset_500_EMPRESAS_v2/CLX
# Moved AIG_completo.csv to ./Dataset_500_EMPRESAS_v2/AIG
# Moved OMC_completo.csv to ./Dataset_500_EMPRESAS_v2/OMC
# Moved TRMB_completo.csv to ./Dataset_500_EMPRESAS_v2/TRMB
# Moved MKC_completo.csv to ./Dataset_500_EMPRESAS_v2/MKC
# Moved UAL_completo.csv to ./Dataset_500_EMPRESAS_v2/UAL
# Moved GEV_completo.csv to ./Dataset_500_EMPRESAS_v2/GEV
# Moved VICI_completo.csv to ./Dataset_500_EMPRESAS_v2/VICI
# Moved AVGO_completo.csv to ./Dataset_500_EMPRESAS_v2/AVGO
# Moved CFG_completo.csv to ./Dataset_500_EMPRESAS_v2/CFG
# Moved EMN_completo.csv to ./Dataset_500_EMPRESAS_v2/EMN
# Moved PSA_completo.csv to ./Dataset_500_EMPRESAS_v2/PSA
# Moved BSX_completo.csv to ./Dataset_500_EMPRESAS_v2/BSX
# Moved IEX_completo.csv to ./Dataset_500_EMPRESAS_v2/IEX
# Moved FAST_completo.csv to ./Dataset_500_EMPRESAS_v2/FAST
# Moved HUBB_completo.csv to ./Dataset_500_EMPRESAS_v2/HUBB
# Moved CDW_completo.csv to ./Dataset_500_EMPRESAS_v2/CDW
# Moved KIM_completo.csv to ./Dataset_500_EMPRESAS_v2/KIM
# Moved DD_completo.csv to ./Dataset_500_EMPRESAS_v2/DD
# Moved XEL_completo.csv to ./Dataset_500_EMPRESAS_v2/XEL
# Moved EXE_completo.csv to ./Dataset_500_EMPRESAS_v2/EXE
# Moved L_completo.csv to ./Dataset_500_EMPRESAS_v2/L
# Moved AWK_completo.csv to ./Dataset_500_EMPRESAS_v2/AWK
# Moved AXP_completo.csv to ./Dataset_500_EMPRESAS_v2/AXP
# Moved FE_completo.csv to ./Dataset_500_EMPRESAS_v2/FE
# Moved DAY_completo.csv to ./Dataset_500_EMPRESAS_v2/DAY
# Moved GILD_completo.csv to ./Dataset_500_EMPRESAS_v2/GILD
# Moved DAL_completo.csv to ./Dataset_500_EMPRESAS_v2/DAL
# Moved CME_completo.csv to ./Dataset_500_EMPRESAS_v2/CME
# Moved SLB_completo.csv to ./Dataset_500_EMPRESAS_v2/SLB
# Moved DHI_completo.csv to ./Dataset_500_EMPRESAS_v2/DHI
# Moved LUV_completo.csv to ./Dataset_500_EMPRESAS_v2/LUV
# Moved GS_completo.csv to ./Dataset_500_EMPRESAS_v2/GS
# Moved CCI_completo.csv to ./Dataset_500_EMPRESAS_v2/CCI
# Moved MRK_completo.csv to ./Dataset_500_EMPRESAS_v2/MRK
# Moved CPRT_completo.csv to ./Dataset_500_EMPRESAS_v2/CPRT
# Moved MCK_completo.csv to ./Dataset_500_EMPRESAS_v2/MCK
# Moved AME_completo.csv to ./Dataset_500_EMPRESAS_v2/AME
# Moved MTCH_completo.csv to ./Dataset_500_EMPRESAS_v2/MTCH
# Moved KDP_completo.csv to ./Dataset_500_EMPRESAS_v2/KDP
# Moved APTV_completo.csv to ./Dataset_500_EMPRESAS_v2/APTV
# Moved ALLE_completo.csv to ./Dataset_500_EMPRESAS_v2/ALLE
# Moved MO_completo.csv to ./Dataset_500_EMPRESAS_v2/MO
# Moved TSN_completo.csv to ./Dataset_500_EMPRESAS_v2/TSN
# Moved CBOE_completo.csv to ./Dataset_500_EMPRESAS_v2/CBOE
# Moved MTD_completo.csv to ./Dataset_500_EMPRESAS_v2/MTD
# Moved FI_completo.csv to ./Dataset_500_EMPRESAS_v2/FI
# Moved CARR_completo.csv to ./Dataset_500_EMPRESAS_v2/CARR
# Moved COST_completo.csv to ./Dataset_500_EMPRESAS_v2/COST
# Moved EPAM_completo.csv to ./Dataset_500_EMPRESAS_v2/EPAM
# Moved MCD_completo.csv to ./Dataset_500_EMPRESAS_v2/MCD
# Moved BA_completo.csv to ./Dataset_500_EMPRESAS_v2/BA
# Moved A_completo.csv to ./Dataset_500_EMPRESAS_v2/A
# Moved ENPH_completo.csv to ./Dataset_500_EMPRESAS_v2/ENPH
# Moved DE_completo.csv to ./Dataset_500_EMPRESAS_v2/DE
# Moved DECK_completo.csv to ./Dataset_500_EMPRESAS_v2/DECK
# Moved RTX_completo.csv to ./Dataset_500_EMPRESAS_v2/RTX
# Moved LMT_completo.csv to ./Dataset_500_EMPRESAS_v2/LMT
# Moved ADBE_completo.csv to ./Dataset_500_EMPRESAS_v2/ADBE
# Moved BKNG_completo.csv to ./Dataset_500_EMPRESAS_v2/BKNG
# Moved PAYX_completo.csv to ./Dataset_500_EMPRESAS_v2/PAYX
# Moved SOLV_completo.csv to ./Dataset_500_EMPRESAS_v2/SOLV
# Moved NSC_completo.csv to ./Dataset_500_EMPRESAS_v2/NSC
# Moved PRU_completo.csv to ./Dataset_500_EMPRESAS_v2/PRU
# Moved KMX_completo.csv to ./Dataset_500_EMPRESAS_v2/KMX
# Moved IRM_completo.csv to ./Dataset_500_EMPRESAS_v2/IRM
# Moved MAS_completo.csv to ./Dataset_500_EMPRESAS_v2/MAS
# Moved CCL_completo.csv to ./Dataset_500_EMPRESAS_v2/CCL
# Moved OTIS_completo.csv to ./Dataset_500_EMPRESAS_v2/OTIS
# Moved CSCO_completo.csv to ./Dataset_500_EMPRESAS_v2/CSCO
# Moved KVUE_completo.csv to ./Dataset_500_EMPRESAS_v2/KVUE
# Moved REGN_completo.csv to ./Dataset_500_EMPRESAS_v2/REGN
# Moved CMCSA_completo.csv to ./Dataset_500_EMPRESAS_v2/CMCSA
# Moved MMM_completo.csv to ./Dataset_500_EMPRESAS_v2/MMM
# Moved WYNN_completo.csv to ./Dataset_500_EMPRESAS_v2/WYNN
# Moved SW_completo.csv to ./Dataset_500_EMPRESAS_v2/SW
# Moved CTRA_completo.csv to ./Dataset_500_EMPRESAS_v2/CTRA
# Moved HRL_completo.csv to ./Dataset_500_EMPRESAS_v2/HRL
# Moved KMI_completo.csv to ./Dataset_500_EMPRESAS_v2/KMI
# Moved META_completo.csv to ./Dataset_500_EMPRESAS_v2/META
# Moved HST_completo.csv to ./Dataset_500_EMPRESAS_v2/HST
# Moved CAH_completo.csv to ./Dataset_500_EMPRESAS_v2/CAH
# Moved AEP_completo.csv to ./Dataset_500_EMPRESAS_v2/AEP
# Moved VLO_completo.csv to ./Dataset_500_EMPRESAS_v2/VLO
# Moved NXPI_completo.csv to ./Dataset_500_EMPRESAS_v2/NXPI
# Moved CRM_completo.csv to ./Dataset_500_EMPRESAS_v2/CRM
# Moved CEG_completo.csv to ./Dataset_500_EMPRESAS_v2/CEG
# Moved EXC_completo.csv to ./Dataset_500_EMPRESAS_v2/EXC
# Moved ULTA_completo.csv to ./Dataset_500_EMPRESAS_v2/ULTA
# Moved PPG_completo.csv to ./Dataset_500_EMPRESAS_v2/PPG
# Moved GIS_completo.csv to ./Dataset_500_EMPRESAS_v2/GIS
# Moved DXCM_completo.csv to ./Dataset_500_EMPRESAS_v2/DXCM
# Moved WDAY_completo.csv to ./Dataset_500_EMPRESAS_v2/WDAY
# Moved APH_completo.csv to ./Dataset_500_EMPRESAS_v2/APH
# Moved TPL_completo.csv to ./Dataset_500_EMPRESAS_v2/TPL
# Moved CB_completo.csv to ./Dataset_500_EMPRESAS_v2/CB
# Moved ABT_completo.csv to ./Dataset_500_EMPRESAS_v2/ABT
# Moved JKHY_completo.csv to ./Dataset_500_EMPRESAS_v2/JKHY
# Moved NUE_completo.csv to ./Dataset_500_EMPRESAS_v2/NUE
# Moved HAL_completo.csv to ./Dataset_500_EMPRESAS_v2/HAL
# Moved FCX_completo.csv to ./Dataset_500_EMPRESAS_v2/FCX
# Moved NOC_completo.csv to ./Dataset_500_EMPRESAS_v2/NOC
# Moved MSCI_completo.csv to ./Dataset_500_EMPRESAS_v2/MSCI
# Moved MAA_completo.csv to ./Dataset_500_EMPRESAS_v2/MAA
# Moved BAX_completo.csv to ./Dataset_500_EMPRESAS_v2/BAX
# Moved DHR_completo.csv to ./Dataset_500_EMPRESAS_v2/DHR
# Moved ADSK_completo.csv to ./Dataset_500_EMPRESAS_v2/ADSK
# Moved LRCX_completo.csv to ./Dataset_500_EMPRESAS_v2/LRCX
# Moved DELL_completo.csv to ./Dataset_500_EMPRESAS_v2/DELL
# Moved GM_completo.csv to ./Dataset_500_EMPRESAS_v2/GM
# Moved AEE_completo.csv to ./Dataset_500_EMPRESAS_v2/AEE
# Moved CRL_completo.csv to ./Dataset_500_EMPRESAS_v2/CRL
# Moved PNW_completo.csv to ./Dataset_500_EMPRESAS_v2/PNW
# Moved EW_completo.csv to ./Dataset_500_EMPRESAS_v2/EW
# Moved KO_completo.csv to ./Dataset_500_EMPRESAS_v2/KO
# Moved REG_completo.csv to ./Dataset_500_EMPRESAS_v2/REG
# Moved ADI_completo.csv to ./Dataset_500_EMPRESAS_v2/ADI
# Moved GNRC_completo.csv to ./Dataset_500_EMPRESAS_v2/GNRC
# Moved TSCO_completo.csv to ./Dataset_500_EMPRESAS_v2/TSCO
# Moved AOS_completo.csv to ./Dataset_500_EMPRESAS_v2/AOS
# Moved NEM_completo.csv to ./Dataset_500_EMPRESAS_v2/NEM
# Moved NOW_completo.csv to ./Dataset_500_EMPRESAS_v2/NOW
# Moved STLD_completo.csv to ./Dataset_500_EMPRESAS_v2/STLD
# Moved EFX_completo.csv to ./Dataset_500_EMPRESAS_v2/EFX
# Moved WELL_completo.csv to ./Dataset_500_EMPRESAS_v2/WELL
# Moved RF_completo.csv to ./Dataset_500_EMPRESAS_v2/RF
# Moved F_completo.csv to ./Dataset_500_EMPRESAS_v2/F
# Moved HSY_completo.csv to ./Dataset_500_EMPRESAS_v2/HSY
# Moved FTNT_completo.csv to ./Dataset_500_EMPRESAS_v2/FTNT
# Moved BKR_completo.csv to ./Dataset_500_EMPRESAS_v2/BKR
# Moved MLM_completo.csv to ./Dataset_500_EMPRESAS_v2/MLM
# Moved EIX_completo.csv to ./Dataset_500_EMPRESAS_v2/EIX
# Moved GOOGL_completo.csv to ./Dataset_500_EMPRESAS_v2/GOOGL
# Moved KEYS_completo.csv to ./Dataset_500_EMPRESAS_v2/KEYS
# Moved ICE_completo.csv to ./Dataset_500_EMPRESAS_v2/ICE
# Moved APD_completo.csv to ./Dataset_500_EMPRESAS_v2/APD
# Moved VRTX_completo.csv to ./Dataset_500_EMPRESAS_v2/VRTX
# Moved GEN_completo.csv to ./Dataset_500_EMPRESAS_v2/GEN
# Moved SMCI_completo.csv to ./Dataset_500_EMPRESAS_v2/SMCI
# Moved LIN_completo.csv to ./Dataset_500_EMPRESAS_v2/LIN
# Moved INCY_completo.csv to ./Dataset_500_EMPRESAS_v2/INCY
# Moved FSLR_completo.csv to ./Dataset_500_EMPRESAS_v2/FSLR
# Moved EBAY_completo.csv to ./Dataset_500_EMPRESAS_v2/EBAY
# Moved TPR_completo.csv to ./Dataset_500_EMPRESAS_v2/TPR
# Moved AVY_completo.csv to ./Dataset_500_EMPRESAS_v2/AVY
# Moved SBAC_completo.csv to ./Dataset_500_EMPRESAS_v2/SBAC
# Moved MHK_completo.csv to ./Dataset_500_EMPRESAS_v2/MHK
# Moved STX_completo.csv to ./Dataset_500_EMPRESAS_v2/STX
# Moved NDSN_completo.csv to ./Dataset_500_EMPRESAS_v2/NDSN
# Moved MDT_completo.csv to ./Dataset_500_EMPRESAS_v2/MDT
# Moved PM_completo.csv to ./Dataset_500_EMPRESAS_v2/PM
# Moved UBER_completo.csv to ./Dataset_500_EMPRESAS_v2/UBER
# Moved PTC_completo.csv to ./Dataset_500_EMPRESAS_v2/PTC
# Moved DDOG_completo.csv to ./Dataset_500_EMPRESAS_v2/DDOG
# Moved CMI_completo.csv to ./Dataset_500_EMPRESAS_v2/CMI
# Moved MS_completo.csv to ./Dataset_500_EMPRESAS_v2/MS
# Moved WTW_completo.csv to ./Dataset_500_EMPRESAS_v2/WTW
# Moved TFC_completo.csv to ./Dataset_500_EMPRESAS_v2/TFC
# Moved HAS_completo.csv to ./Dataset_500_EMPRESAS_v2/HAS
# Moved HCA_completo.csv to ./Dataset_500_EMPRESAS_v2/HCA
# Moved VTRS_completo.csv to ./Dataset_500_EMPRESAS_v2/VTRS
# Moved GDDY_completo.csv to ./Dataset_500_EMPRESAS_v2/GDDY
# Moved TTD_completo.csv to ./Dataset_500_EMPRESAS_v2/TTD
# Moved BIIB_completo.csv to ./Dataset_500_EMPRESAS_v2/BIIB
# Moved CPT_completo.csv to ./Dataset_500_EMPRESAS_v2/CPT
# Moved TRV_completo.csv to ./Dataset_500_EMPRESAS_v2/TRV
# Moved AZO_completo.csv to ./Dataset_500_EMPRESAS_v2/AZO
# Moved ZBH_completo.csv to ./Dataset_500_EMPRESAS_v2/ZBH
# Moved CMS_completo.csv to ./Dataset_500_EMPRESAS_v2/CMS
# Moved MKTX_completo.csv to ./Dataset_500_EMPRESAS_v2/MKTX
# Moved SYK_completo.csv to ./Dataset_500_EMPRESAS_v2/SYK
# Moved MAR_completo.csv to ./Dataset_500_EMPRESAS_v2/MAR
# Moved AMGN_completo.csv to ./Dataset_500_EMPRESAS_v2/AMGN
# Moved AKAM_completo.csv to ./Dataset_500_EMPRESAS_v2/AKAM
# Moved XOM_completo.csv to ./Dataset_500_EMPRESAS_v2/XOM
# Moved USB_completo.csv to ./Dataset_500_EMPRESAS_v2/USB
# Moved D_completo.csv to ./Dataset_500_EMPRESAS_v2/D
# Moved HSIC_completo.csv to ./Dataset_500_EMPRESAS_v2/HSIC
# Moved VRSK_completo.csv to ./Dataset_500_EMPRESAS_v2/VRSK
# Moved EMR_completo.csv to ./Dataset_500_EMPRESAS_v2/EMR
# Moved ACN_completo.csv to ./Dataset_500_EMPRESAS_v2/ACN
# Moved DIS_completo.csv to ./Dataset_500_EMPRESAS_v2/DIS
# Moved T_completo.csv to ./Dataset_500_EMPRESAS_v2/T
# Moved MCO_completo.csv to ./Dataset_500_EMPRESAS_v2/MCO
# Moved ABBV_completo.csv to ./Dataset_500_EMPRESAS_v2/ABBV
# Moved EVRG_completo.csv to ./Dataset_500_EMPRESAS_v2/EVRG
# Moved MSFT_completo.csv to ./Dataset_500_EMPRESAS_v2/MSFT
# Moved SRE_completo.csv to ./Dataset_500_EMPRESAS_v2/SRE
# Moved LHX_completo.csv to ./Dataset_500_EMPRESAS_v2/LHX
# Moved DUK_completo.csv to ./Dataset_500_EMPRESAS_v2/DUK
# Moved ROL_completo.csv to ./Dataset_500_EMPRESAS_v2/ROL
# Moved IP_completo.csv to ./Dataset_500_EMPRESAS_v2/IP
# Moved CINF_completo.csv to ./Dataset_500_EMPRESAS_v2/CINF
# Moved MPWR_completo.csv to ./Dataset_500_EMPRESAS_v2/MPWR
# Moved LKQ_completo.csv to ./Dataset_500_EMPRESAS_v2/LKQ
# Moved CZR_completo.csv to ./Dataset_500_EMPRESAS_v2/CZR
# Moved WM_completo.csv to ./Dataset_500_EMPRESAS_v2/WM
# Moved FDX_completo.csv to ./Dataset_500_EMPRESAS_v2/FDX
# Moved NVR_completo.csv to ./Dataset_500_EMPRESAS_v2/NVR
# Moved FTV_completo.csv to ./Dataset_500_EMPRESAS_v2/FTV
# Moved COR_completo.csv to ./Dataset_500_EMPRESAS_v2/COR
# Moved CAT_completo.csv to ./Dataset_500_EMPRESAS_v2/CAT
# Moved NVDA_completo.csv to ./Dataset_500_EMPRESAS_v2/NVDA
# Moved AVB_completo.csv to ./Dataset_500_EMPRESAS_v2/AVB
# Moved TER_completo.csv to ./Dataset_500_EMPRESAS_v2/TER
# Moved NI_completo.csv to ./Dataset_500_EMPRESAS_v2/NI
# Moved BEN_completo.csv to ./Dataset_500_EMPRESAS_v2/BEN
# Moved GD_completo.csv to ./Dataset_500_EMPRESAS_v2/GD
# Moved EQIX_completo.csv to ./Dataset_500_EMPRESAS_v2/EQIX
# Moved LULU_completo.csv to ./Dataset_500_EMPRESAS_v2/LULU
# Moved RVTY_completo.csv to ./Dataset_500_EMPRESAS_v2/RVTY
# Moved CTSH_completo.csv to ./Dataset_500_EMPRESAS_v2/CTSH
# Moved PANW_completo.csv to ./Dataset_500_EMPRESAS_v2/PANW
# Moved URI_completo.csv to ./Dataset_500_EMPRESAS_v2/URI
# Moved SPGI_completo.csv to ./Dataset_500_EMPRESAS_v2/SPGI
# Moved STE_completo.csv to ./Dataset_500_EMPRESAS_v2/STE
# Moved DLR_completo.csv to ./Dataset_500_EMPRESAS_v2/DLR
# Moved XYZ_completo.csv to ./Dataset_500_EMPRESAS_v2/XYZ
# Moved WMB_completo.csv to ./Dataset_500_EMPRESAS_v2/WMB
# Moved KKR_completo.csv to ./Dataset_500_EMPRESAS_v2/KKR
# Moved CPAY_completo.csv to ./Dataset_500_EMPRESAS_v2/CPAY
# Moved RSG_completo.csv to ./Dataset_500_EMPRESAS_v2/RSG
# Moved MMC_completo.csv to ./Dataset_500_EMPRESAS_v2/MMC
# Moved PODD_completo.csv to ./Dataset_500_EMPRESAS_v2/PODD
# Moved ZTS_completo.csv to ./Dataset_500_EMPRESAS_v2/ZTS
# Moved WEC_completo.csv to ./Dataset_500_EMPRESAS_v2/WEC
# Moved WAB_completo.csv to ./Dataset_500_EMPRESAS_v2/WAB
# Moved MOS_completo.csv to ./Dataset_500_EMPRESAS_v2/MOS
# Moved WSM_completo.csv to ./Dataset_500_EMPRESAS_v2/WSM
# Moved APA_completo.csv to ./Dataset_500_EMPRESAS_v2/APA
# Moved AON_completo.csv to ./Dataset_500_EMPRESAS_v2/AON
# Moved WFC_completo.csv to ./Dataset_500_EMPRESAS_v2/WFC
# Moved DG_completo.csv to ./Dataset_500_EMPRESAS_v2/DG
# Moved CI_completo.csv to ./Dataset_500_EMPRESAS_v2/CI
# Moved UPS_completo.csv to ./Dataset_500_EMPRESAS_v2/UPS
# Moved JNJ_completo.csv to ./Dataset_500_EMPRESAS_v2/JNJ
# Moved IPG_completo.csv to ./Dataset_500_EMPRESAS_v2/IPG
# Moved BRK-B_completo.csv to ./Dataset_500_EMPRESAS_v2/BRK-B
# Moved NKE_completo.csv to ./Dataset_500_EMPRESAS_v2/NKE
# Moved CF_completo.csv to ./Dataset_500_EMPRESAS_v2/CF
# Moved TRGP_completo.csv to ./Dataset_500_EMPRESAS_v2/TRGP
# Moved PFE_completo.csv to ./Dataset_500_EMPRESAS_v2/PFE
# Moved WAT_completo.csv to ./Dataset_500_EMPRESAS_v2/WAT
# Moved ATO_completo.csv to ./Dataset_500_EMPRESAS_v2/ATO
# Moved LEN_completo.csv to ./Dataset_500_EMPRESAS_v2/LEN
# Moved PPL_completo.csv to ./Dataset_500_EMPRESAS_v2/PPL
# Moved ARE_completo.csv to ./Dataset_500_EMPRESAS_v2/ARE
# Moved KR_completo.csv to ./Dataset_500_EMPRESAS_v2/KR
# Moved STT_completo.csv to ./Dataset_500_EMPRESAS_v2/STT
# Moved ESS_completo.csv to ./Dataset_500_EMPRESAS_v2/ESS
# Moved AIZ_completo.csv to ./Dataset_500_EMPRESAS_v2/AIZ
# Moved JCI_completo.csv to ./Dataset_500_EMPRESAS_v2/JCI
# Moved TSLA_completo.csv to ./Dataset_500_EMPRESAS_v2/TSLA
# Moved DVA_completo.csv to ./Dataset_500_EMPRESAS_v2/DVA
# Moved WBA_completo.csv to ./Dataset_500_EMPRESAS_v2/WBA
# Moved CHTR_completo.csv to ./Dataset_500_EMPRESAS_v2/CHTR
# Moved DGX_completo.csv to ./Dataset_500_EMPRESAS_v2/DGX
# Moved HPQ_completo.csv to ./Dataset_500_EMPRESAS_v2/HPQ
# Moved LYV_completo.csv to ./Dataset_500_EMPRESAS_v2/LYV
# Moved MET_completo.csv to ./Dataset_500_EMPRESAS_v2/MET
# Moved ELV_completo.csv to ./Dataset_500_EMPRESAS_v2/ELV
# Moved COP_completo.csv to ./Dataset_500_EMPRESAS_v2/COP
# Moved VLTO_completo.csv to ./Dataset_500_EMPRESAS_v2/VLTO
# Moved AXON_completo.csv to ./Dataset_500_EMPRESAS_v2/AXON
# Moved ALL_completo.csv to ./Dataset_500_EMPRESAS_v2/ALL
# Moved COO_completo.csv to ./Dataset_500_EMPRESAS_v2/COO
# Moved ROK_completo.csv to ./Dataset_500_EMPRESAS_v2/ROK
# Moved IT_completo.csv to ./Dataset_500_EMPRESAS_v2/IT
# Moved EG_completo.csv to ./Dataset_500_EMPRESAS_v2/EG
# Moved MRNA_completo.csv to ./Dataset_500_EMPRESAS_v2/MRNA
# Moved ETN_completo.csv to ./Dataset_500_EMPRESAS_v2/ETN
# Moved MA_completo.csv to ./Dataset_500_EMPRESAS_v2/MA
# Moved ISRG_completo.csv to ./Dataset_500_EMPRESAS_v2/ISRG
# Moved C_completo.csv to ./Dataset_500_EMPRESAS_v2/C
# Moved BAC_completo.csv to ./Dataset_500_EMPRESAS_v2/BAC
# Moved MNST_completo.csv to ./Dataset_500_EMPRESAS_v2/MNST
# Moved FANG_completo.csv to ./Dataset_500_EMPRESAS_v2/FANG
# Moved PCG_completo.csv to ./Dataset_500_EMPRESAS_v2/PCG
# Moved CSGP_completo.csv to ./Dataset_500_EMPRESAS_v2/CSGP
# Moved V_completo.csv to ./Dataset_500_EMPRESAS_v2/V
# Moved AMZN_completo.csv to ./Dataset_500_EMPRESAS_v2/AMZN
# Moved ON_completo.csv to ./Dataset_500_EMPRESAS_v2/ON
# Moved TTWO_completo.csv to ./Dataset_500_EMPRESAS_v2/TTWO
# Moved BR_completo.csv to ./Dataset_500_EMPRESAS_v2/BR
# Moved DASH_completo.csv to ./Dataset_500_EMPRESAS_v2/DASH
# Moved LNT_completo.csv to ./Dataset_500_EMPRESAS_v2/LNT
# Moved CVX_completo.csv to ./Dataset_500_EMPRESAS_v2/CVX
# Moved AAPL_completo.csv to ./Dataset_500_EMPRESAS_v2/AAPL
# Moved AMP_completo.csv to ./Dataset_500_EMPRESAS_v2/AMP
# Moved OXY_completo.csv to ./Dataset_500_EMPRESAS_v2/OXY
# Moved UDR_completo.csv to ./Dataset_500_EMPRESAS_v2/UDR
# Moved SYY_completo.csv to ./Dataset_500_EMPRESAS_v2/SYY
# Moved SWK_completo.csv to ./Dataset_500_EMPRESAS_v2/SWK
# Moved FDS_completo.csv to ./Dataset_500_EMPRESAS_v2/FDS
# Moved ERIE_completo.csv to ./Dataset_500_EMPRESAS_v2/ERIE
# Moved WY_completo.csv to ./Dataset_500_EMPRESAS_v2/WY
# Moved TECH_completo.csv to ./Dataset_500_EMPRESAS_v2/TECH
# Moved TT_completo.csv to ./Dataset_500_EMPRESAS_v2/TT
# Moved NEE_completo.csv to ./Dataset_500_EMPRESAS_v2/NEE
# Moved BK_completo.csv to ./Dataset_500_EMPRESAS_v2/BK
# Moved GE_completo.csv to ./Dataset_500_EMPRESAS_v2/GE
# Moved DOV_completo.csv to ./Dataset_500_EMPRESAS_v2/DOV
# Moved PNC_completo.csv to ./Dataset_500_EMPRESAS_v2/PNC
# Moved MTB_completo.csv to ./Dataset_500_EMPRESAS_v2/MTB
# Moved EQR_completo.csv to ./Dataset_500_EMPRESAS_v2/EQR
# Moved NTRS_completo.csv to ./Dataset_500_EMPRESAS_v2/NTRS
# Moved CVS_completo.csv to ./Dataset_500_EMPRESAS_v2/CVS
# Moved COF_completo.csv to ./Dataset_500_EMPRESAS_v2/COF
# Moved K_completo.csv to ./Dataset_500_EMPRESAS_v2/K
# Moved VMC_completo.csv to ./Dataset_500_EMPRESAS_v2/VMC
# Moved VST_completo.csv to ./Dataset_500_EMPRESAS_v2/VST
# Moved WRB_completo.csv to ./Dataset_500_EMPRESAS_v2/WRB
# Moved TMUS_completo.csv to ./Dataset_500_EMPRESAS_v2/TMUS
# Moved ABNB_completo.csv to ./Dataset_500_EMPRESAS_v2/ABNB
# Moved SYF_completo.csv to ./Dataset_500_EMPRESAS_v2/SYF
# Moved PEG_completo.csv to ./Dataset_500_EMPRESAS_v2/PEG
# Moved HIG_completo.csv to ./Dataset_500_EMPRESAS_v2/HIG
# Moved NCLH_completo.csv to ./Dataset_500_EMPRESAS_v2/NCLH
# Moved GL_completo.csv to ./Dataset_500_EMPRESAS_v2/GL
# Moved AES_completo.csv to ./Dataset_500_EMPRESAS_v2/AES
# Moved FOXA_completo.csv to ./Dataset_500_EMPRESAS_v2/FOXA
# Moved GPC_completo.csv to ./Dataset_500_EMPRESAS_v2/GPC
# Moved PLD_completo.csv to ./Dataset_500_EMPRESAS_v2/PLD
# Moved PHM_completo.csv to ./Dataset_500_EMPRESAS_v2/PHM
# Moved CPB_completo.csv to ./Dataset_500_EMPRESAS_v2/CPB
# Moved LW_completo.csv to ./Dataset_500_EMPRESAS_v2/LW
# Moved ORCL_completo.csv to ./Dataset_500_EMPRESAS_v2/ORCL
# Moved EA_completo.csv to ./Dataset_500_EMPRESAS_v2/EA
# Moved PNR_completo.csv to ./Dataset_500_EMPRESAS_v2/PNR
# Moved NDAQ_completo.csv to ./Dataset_500_EMPRESAS_v2/NDAQ
# Moved PGR_completo.csv to ./Dataset_500_EMPRESAS_v2/PGR
# Moved BLDR_completo.csv to ./Dataset_500_EMPRESAS_v2/BLDR
# Moved CSX_completo.csv to ./Dataset_500_EMPRESAS_v2/CSX
# Moved EOG_completo.csv to ./Dataset_500_EMPRESAS_v2/EOG
# Moved AJG_completo.csv to ./Dataset_500_EMPRESAS_v2/AJG
# Moved GRMN_completo.csv to ./Dataset_500_EMPRESAS_v2/GRMN
# Moved AMAT_completo.csv to ./Dataset_500_EMPRESAS_v2/AMAT
# Moved SBUX_completo.csv to ./Dataset_500_EMPRESAS_v2/SBUX
# Moved BBY_completo.csv to ./Dataset_500_EMPRESAS_v2/BBY
# Moved CDNS_completo.csv to ./Dataset_500_EMPRESAS_v2/CDNS
# Moved EL_completo.csv to ./Dataset_500_EMPRESAS_v2/EL
# Moved BF-B_completo.csv to ./Dataset_500_EMPRESAS_v2/BF-B
# Moved TMO_completo.csv to ./Dataset_500_EMPRESAS_v2/TMO
# Moved BDX_completo.csv to ./Dataset_500_EMPRESAS_v2/BDX
# Moved CHD_completo.csv to ./Dataset_500_EMPRESAS_v2/CHD
# Moved CHRW_completo.csv to ./Dataset_500_EMPRESAS_v2/CHRW
# Moved ALGN_completo.csv to ./Dataset_500_EMPRESAS_v2/ALGN
# Moved NWS_completo.csv to ./Dataset_500_EMPRESAS_v2/NWS
# Moved ALB_completo.csv to ./Dataset_500_EMPRESAS_v2/ALB
# Moved GWW_completo.csv to ./Dataset_500_EMPRESAS_v2/GWW
# Moved BG_completo.csv to ./Dataset_500_EMPRESAS_v2/BG
# Moved ZBRA_completo.csv to ./Dataset_500_EMPRESAS_v2/ZBRA
# Moved MDLZ_completo.csv to ./Dataset_500_EMPRESAS_v2/MDLZ
# Moved ROP_completo.csv to ./Dataset_500_EMPRESAS_v2/ROP
# Moved J_completo.csv to ./Dataset_500_EMPRESAS_v2/J
# Moved HUM_completo.csv to ./Dataset_500_EMPRESAS_v2/HUM
# Moved STZ_completo.csv to ./Dataset_500_EMPRESAS_v2/STZ
# Moved CAG_completo.csv to ./Dataset_500_EMPRESAS_v2/CAG
# Moved ADP_completo.csv to ./Dataset_500_EMPRESAS_v2/ADP
# Moved VRSN_completo.csv to ./Dataset_500_EMPRESAS_v2/VRSN
# Moved XYL_completo.csv to ./Dataset_500_EMPRESAS_v2/XYL
# Moved MGM_completo.csv to ./Dataset_500_EMPRESAS_v2/MGM
# Moved PKG_completo.csv to ./Dataset_500_EMPRESAS_v2/PKG
# Moved LH_completo.csv to ./Dataset_500_EMPRESAS_v2/LH
# Moved ED_completo.csv to ./Dataset_500_EMPRESAS_v2/ED
# Moved IBM_completo.csv to ./Dataset_500_EMPRESAS_v2/IBM
# Moved EXPE_completo.csv to ./Dataset_500_EMPRESAS_v2/EXPE
# Moved TYL_completo.csv to ./Dataset_500_EMPRESAS_v2/TYL
# Moved CL_completo.csv to ./Dataset_500_EMPRESAS_v2/CL
# Moved APO_completo.csv to ./Dataset_500_EMPRESAS_v2/APO
# Moved PAYC_completo.csv to ./Dataset_500_EMPRESAS_v2/PAYC
# Moved RCL_completo.csv to ./Dataset_500_EMPRESAS_v2/RCL
# Moved LII_completo.csv to ./Dataset_500_EMPRESAS_v2/LII
# Moved IVZ_completo.csv to ./Dataset_500_EMPRESAS_v2/IVZ
# Moved WMT_completo.csv to ./Dataset_500_EMPRESAS_v2/WMT
# Organización completada.

# %%
import pandas as pd
import os
import json

def procesar_ticker(ticker, base_path):
    # Cargar datos históricos
    hist_path = os.path.join(base_path, ticker, f"{ticker}_historico.csv")
    df_hist = pd.read_csv(hist_path, parse_dates=['Date'], index_col='Date')
    
    # Cargar datos financieros
    financial_dfs = []
    for tipo in ['cash_flow', 'balance_sheet', 'income_statement']:
        path = os.path.join(base_path, ticker, f"{ticker}_{tipo}.csv")
        if not os.path.exists(path):
            print(f"Advertencia: No existe {path}")
            continue
        df = pd.read_csv(path, index_col=0)
        df = df.T  # Transponer para que las fechas sean el índice
        df.index = pd.to_datetime(df.index)
        financial_dfs.append(df)
    
    if not financial_dfs:
        print(f"No hay datos financieros para {ticker}")
        return
    
    # Combinar datos financieros
    df_financial = pd.concat(financial_dfs, axis=1)
    
    # Crear índice diario covering el rango de fechas históricas
    start_date = df_hist.index.min()
    end_date = df_hist.index.max()
    idx_diario = pd.date_range(start=start_date, end=end_date, freq='D')
    
    # Reindexar datos financieros al índice diario
    df_financial_diario = df_financial.reindex(idx_diario)
    
    # Forward fill para propagar valores
    df_financial_diario = df_financial_diario.ffill()
    
    # Rellenar con 0 las fechas anteriores al primer reporte financiero
    if not df_financial.empty:
        first_financial_date = df_financial.index.min()
        mask = idx_diario < first_financial_date
        df_financial_diario.loc[mask] = 0
    
    # Combinar con datos históricos
    df_combinado = df_hist.join(df_financial_diario, how='left')
    
    # Cargar sectorKey desde info.json
    info_path = os.path.join(base_path, ticker, f"{ticker}_info.json")
    with open(info_path, 'r') as f:
        info_data = json.load(f)
    sector_key = info_data.get('sectorKey', '')
    
    # Añadir sectorKey como columna
    df_combinado['sectorKey'] = sector_key
    
    # Guardar resultado
    output_path = os.path.join(base_path, f"{ticker}_completo.csv")
    df_combinado.to_csv(output_path, index_label='Date')
    print(f"Guardado: {output_path}")

# Procesar todos los tickers
base_path = './Dataset_500_EMPRESAS_v2'  # Cambia esto si es necesario
tickers = [d for d in os.listdir(base_path) if os.path.isdir(os.path.join(base_path, d))]

for ticker in tickers:
    try:
        procesar_ticker(ticker, base_path)
    except Exception as e:
        print(f"Error procesando {ticker}: {str(e)}")
# Out:
# Guardado: ./Dataset_500_EMPRESAS_v2/CTAS_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/WELL_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/VZ_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/AMZN_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/CNP_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/RCL_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/CAT_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/TFC_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/AAPL_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/BF-B_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/PANW_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/PM_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/KHC_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/TEL_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/CMCSA_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/GRMN_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/ANET_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/BRO_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/CAH_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/SW_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/SOLV_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/TROW_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/PODD_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/FSLR_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/PFE_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/REG_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/APTV_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/CDW_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/MAR_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/VRSN_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/FITB_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/KMI_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/UBER_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/SPGI_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/ALLE_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/SYK_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/MMC_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/MPWR_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/DXCM_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/PEP_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/FRT_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/SNPS_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/PLD_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/GOOG_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/MMM_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/EMN_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/NXPI_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/PCG_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/AMT_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/ADI_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/MAA_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/WSM_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/HWM_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/MAS_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/FTV_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/CAG_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/MGM_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/CNC_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/VLO_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/UPS_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/PLTR_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/CME_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/NWS_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/EMR_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/OKE_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/SYY_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/GILD_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/SNA_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/MS_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/PTC_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/AXON_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/WMT_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/HUBB_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/ULTA_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/DG_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/CVX_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/NCLH_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/UHS_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/GPN_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/DLR_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/MO_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/CPT_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/TXN_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/KLAC_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/INTC_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/BK_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/NI_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/LII_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/TTWO_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/HCA_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/GS_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/TMUS_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/BLK_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/CDNS_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/LOW_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/LIN_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/MA_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/HII_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/CZR_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/PRU_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/BX_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/KVUE_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/CTSH_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/SHW_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/MCHP_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/VTR_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/HIG_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/MU_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/TXT_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/ACGL_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/APD_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/HD_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/FIS_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/IPG_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/NDSN_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/DDOG_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/UNP_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/AMAT_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/LLY_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/WBD_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/FOX_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/ERIE_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/NTAP_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/FICO_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/TTD_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/MSI_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/AKAM_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/SBAC_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/WAB_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/REGN_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/RSG_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/IR_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/ENPH_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/AWK_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/EXR_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/HAL_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/MRNA_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/IQV_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/VST_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/EW_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/LMT_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/TYL_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/CI_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/PPL_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/EQT_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/EPAM_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/SLB_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/CRL_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/CSGP_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/EL_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/JKHY_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/LKQ_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/WFC_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/CRWD_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/WYNN_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/PSX_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/MRK_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/JNJ_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/INVH_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/QCOM_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/LNT_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/BAC_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/CF_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/BRK-B_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/IT_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/DHI_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/XYZ_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/LW_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/LHX_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/FE_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/BBY_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/IRM_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/TPL_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/TSLA_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/DGX_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/CRM_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/EQR_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/HBAN_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/COST_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/FDS_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/ED_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/BAX_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/DHR_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/GOOGL_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/HSIC_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/WEC_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/ALB_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/MOS_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/WM_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/ICE_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/STX_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/LVS_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/STLD_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/CCL_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/TMO_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/AIZ_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/PHM_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/MSFT_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/TGT_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/ALL_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/META_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/BSX_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/FAST_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/ELV_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/SWK_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/MOH_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/ABBV_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/AFL_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/OTIS_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/MCD_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/RMD_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/AJG_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/WTW_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/IFF_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/PGR_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/HPE_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/CEG_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/EFX_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/MET_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/COR_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/EQIX_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/LYB_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/TDG_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/NFLX_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/VTRS_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/PNR_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/KEY_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/ACN_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/CINF_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/COO_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/AEP_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/CHRW_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/COF_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/LYV_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/VMC_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/ALGN_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/HSY_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/T_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/HPQ_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/GEN_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/ORCL_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/CBRE_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/CHTR_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/DUK_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/TAP_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/NUE_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/FFIV_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/MCK_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/A_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/DELL_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/AIG_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/EBAY_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/DPZ_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/WY_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/F_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/NTRS_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/O_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/RF_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/CFG_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/STE_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/AEE_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/PYPL_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/DRI_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/NRG_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/CMG_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/IBM_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/WST_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/ADP_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/PEG_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/MKC_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/CMI_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/AMD_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/MHK_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/KDP_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/HRL_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/PG_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/INCY_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/BXP_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/XOM_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/USB_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/SO_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/KMX_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/LRCX_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/CHD_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/FOXA_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/DTE_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/BLDR_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/NDAQ_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/JBHT_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/SMCI_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/CPAY_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/VRSK_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/PFG_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/TER_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/ROP_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/KKR_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/AME_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/XEL_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/RJF_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/KMB_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/COIN_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/SPG_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/DLTR_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/TJX_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/ROL_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/SBUX_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/YUM_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/CMS_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/PH_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/ROK_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/MDLZ_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/PCAR_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/MDT_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/EVRG_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/SYF_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/ABT_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/ADM_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/AMP_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/OMC_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/WDAY_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/NEE_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/NOW_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/CSX_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/CARR_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/AZO_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/PAYC_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/MPC_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/KR_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/FCX_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/DOW_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/UDR_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/WMB_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/RTX_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/TRV_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/BALL_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/GPC_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/HON_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/WBA_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/BA_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/APA_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/FTNT_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/GE_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/ESS_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/HLT_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/PAYX_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/INTU_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/DD_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/CPB_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/BEN_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/APO_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/WDC_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/BIIB_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/APH_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/GL_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/VICI_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/NVDA_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/JCI_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/NEM_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/AMGN_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/DOV_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/CTVA_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/BG_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/UAL_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/PWR_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/UNH_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/ZTS_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/LEN_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/AVB_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/LDOS_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/GM_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/DIS_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/WAT_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/DE_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/NOC_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/IDXX_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/DASH_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/CSCO_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/MTCH_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/CVS_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/GD_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/AVY_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/DOC_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/BR_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/GDDY_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/KO_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/IVZ_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/PARA_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/AXP_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/FI_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/KEYS_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/AVGO_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/ISRG_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/MTB_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/VLTO_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/ARE_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/HAS_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/EA_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/CTRA_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/ODFL_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/EXC_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/FDX_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/NWSA_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/CBOE_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/MNST_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/ZBRA_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/TPR_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/ES_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/FANG_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/ADSK_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/SJM_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/AMCR_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/ETN_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/XYL_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/BMY_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/EXE_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/ITW_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/DAL_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/TSN_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/CPRT_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/MTD_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/TSCO_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/EG_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/DAY_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/NKE_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/LH_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/GWW_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/CL_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/PSA_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/BDX_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/BKNG_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/ETR_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/ATO_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/CB_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/PPG_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/IP_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/SWKS_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/JBL_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/BKR_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/LULU_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/ON_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/OXY_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/URI_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/HOLX_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/TECH_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/ADBE_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/J_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/POOL_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/EIX_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/MLM_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/C_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/TRMB_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/TT_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/D_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/TRGP_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/DVA_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/GNRC_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/IEX_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/ABNB_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/V_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/SRE_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/AON_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/MKTX_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/EXPD_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/VRTX_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/LUV_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/PNW_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/RL_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/GIS_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/ECL_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/ZBH_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/EOG_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/KIM_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/CLX_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/MCO_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/COP_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/ORLY_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/DECK_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/JPM_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/GEV_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/ROST_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/K_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/DVN_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/RVTY_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/PNC_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/WRB_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/AOS_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/L_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/TKO_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/TDY_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/NSC_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/AES_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/PKG_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/EXPE_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/HUM_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/HST_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/NVR_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/STT_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/CCI_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/GEHC_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/SCHW_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/STZ_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/MSCI_completo.csv
# Guardado: ./Dataset_500_EMPRESAS_v2/GLW_completo.csv

# %%
import pandas as pd
import os
import numpy as np

def limpiar_datos(ticker, input_dir, output_dir):
    # Leer el archivo CSV
    input_path = os.path.join(input_dir, f"{ticker}_completo.csv")
    df = pd.read_csv(input_path)
    
    # Convertir la columna 'Free Cash Flow' a numérico, manejando errores
    df['Free Cash Flow'] = pd.to_numeric(df['Free Cash Flow'], errors='coerce')
    
    # Filtrar filas donde 'Free Cash Flow' no es NaN, vacío ni 0
    df_limpio = df[df['Free Cash Flow'].notna() & (df['Free Cash Flow'] != 0)]
    
    # Guardar el resultado
    output_path = os.path.join(output_dir, f"{ticker}_completo_arreglado.csv")
    df_limpio.to_csv(output_path, index=False)
    print(f"Archivo limpio guardado: {output_path}")

# Directorios de entrada y salida
input_dir = './Dataset_500_completo_v4'  # Cambia esto a la ruta de tus archivos completos
output_dir = './datos_limpios'  # Carpeta para los archivos limpios

# Crear directorio de salida si no existe
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Obtener todos los archivos completos
archivos = [f for f in os.listdir(input_dir) if f.endswith('_completo.csv')]
tickers = [f.split('_')[0] for f in archivos]

# Procesar cada ticker
for ticker in tickers:
    try:
        limpiar_datos(ticker, input_dir, output_dir)
    except Exception as e:
        print(f"Error procesando {ticker}: {str(e)}")

print("Proceso completado. Archivos limpios guardados en:", output_dir)
# Out:
# Archivo limpio guardado: ./datos_limpios/NWSA_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/CF_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/TSCO_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/AJG_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/GEN_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/LOW_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/HIG_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/LYV_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/XOM_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/TEL_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/PODD_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/XYL_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/EMR_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/SBUX_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/PEG_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/ITW_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/ADM_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/PSA_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/CMS_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/WBA_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/DOW_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/O_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/COO_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/DTE_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/DHI_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/POOL_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/FRT_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/JKHY_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/QCOM_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/RF_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/HPQ_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/DPZ_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/VTRS_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/PPG_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/EXR_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/MMM_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/DG_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/FOXA_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/PCAR_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/ATO_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/SCHW_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/MTD_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/KO_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/DIS_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/STT_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/RMD_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/PNW_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/LDOS_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/LMT_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/BAC_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/GEHC_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/IT_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/AEP_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/PLTR_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/NKE_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/GEV_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/CPB_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/EQIX_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/APO_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/AMZN_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/COP_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/GPN_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/MPC_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/APH_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/URI_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/CHTR_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/GWW_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/PANW_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/SWKS_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/DVA_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/MS_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/TPL_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/COST_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/DOV_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/NVR_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/TPR_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/BF-B_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/ADBE_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/TRGP_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/NCLH_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/ZTS_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/LNT_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/LKQ_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/SBAC_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/VRSN_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/FDS_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/BDX_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/ELV_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/CTSH_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/MOH_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/LH_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/TSLA_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/SYY_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/BALL_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/FE_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/OKE_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/IRM_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/CHRW_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/DELL_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/HBAN_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/HUM_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/TRMB_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/AIG_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/PHM_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/ALB_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/TRV_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/UPS_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/CVX_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/KIM_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/JNJ_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/V_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/ED_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/DGX_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/ON_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/VICI_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/FANG_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/NOC_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/PSX_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/MU_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/UAL_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/SWK_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/GRMN_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/CBRE_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/OXY_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/KEYS_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/PFG_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/WDC_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/WRB_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/MTB_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/TER_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/HRL_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/FTV_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/SYF_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/LW_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/IR_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/LEN_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/PPL_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/STX_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/EXPD_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/CPRT_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/LYB_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/PAYX_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/NRG_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/ECL_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/PWR_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/SYK_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/ABBV_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/MCK_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/VMC_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/SO_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/APD_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/NDAQ_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/GOOGL_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/WSM_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/BMY_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/INCY_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/CMG_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/DOC_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/META_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/VST_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/GILD_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/FCX_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/ZBRA_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/AON_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/PNC_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/MSI_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/SPGI_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/KMX_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/RSG_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/CRM_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/WAT_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/MKTX_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/ROL_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/HPE_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/DUK_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/XEL_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/TYL_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/HCA_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/ROK_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/FITB_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/RVTY_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/GM_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/EQR_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/CRWD_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/WMB_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/MRK_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/ALLE_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/MNST_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/D_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/SPG_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/FSLR_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/SW_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/JBHT_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/C_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/VTR_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/DXCM_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/TXN_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/GIS_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/CVS_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/AZO_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/SOLV_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/AVGO_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/GPC_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/FIS_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/NSC_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/CHD_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/HON_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/GS_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/ACGL_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/HSIC_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/SRE_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/CMCSA_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/ETN_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/MDT_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/UNH_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/NEE_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/BEN_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/UHS_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/EXPE_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/KHC_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/MGM_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/RL_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/COIN_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/TMO_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/CCL_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/WDAY_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/AVY_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/LRCX_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/EQT_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/HD_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/MA_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/CTRA_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/MKC_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/UNP_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/GL_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/NOW_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/GDDY_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/AMCR_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/WST_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/EVRG_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/GLW_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/BIIB_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/DDOG_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/IDXX_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/EBAY_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/MRNA_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/FDX_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/ORLY_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/EW_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/PH_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/EIX_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/PKG_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/CL_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/FI_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/CTVA_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/RTX_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/TMUS_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/WELL_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/AEE_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/INTC_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/NDSN_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/DLTR_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/LVS_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/AMT_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/CAH_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/REG_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/CRL_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/DVN_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/TROW_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/KDP_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/WTW_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/AMAT_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/MAS_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/LLY_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/ADSK_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/PEP_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/ROST_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/ORCL_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/ALL_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/IEX_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/TDY_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/MCO_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/TECH_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/CBOE_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/MSFT_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/MET_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/TTD_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/BRO_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/CCI_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/DRI_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/IPG_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/IFF_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/CDW_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/PLD_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/SHW_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/ROP_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/MSCI_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/BK_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/ENPH_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/AKAM_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/MCHP_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/GOOG_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/LULU_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/EXE_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/NUE_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/PAYC_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/CI_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/PM_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/SMCI_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/ALGN_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/SJM_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/AOS_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/PRU_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/ICE_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/USB_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/LHX_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/DAL_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/ABNB_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/CAT_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/MMC_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/HLT_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/WM_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/ULTA_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/AMGN_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/ERIE_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/STZ_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/XYZ_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/HOLX_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/ISRG_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/KMB_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/LUV_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/AXP_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/TT_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/CME_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/BR_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/MAR_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/TFC_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/MTCH_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/APA_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/IVZ_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/TXT_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/ESS_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/EL_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/AMP_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/HII_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/STE_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/CNC_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/DECK_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/EXC_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/NXPI_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/CLX_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/AVB_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/CPT_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/JBL_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/TDG_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/EOG_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/A_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/PGR_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/ES_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/YUM_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/TKO_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/APTV_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/F_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/FTNT_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/COF_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/ETR_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/JCI_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/JPM_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/VLTO_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/FFIV_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/VRTX_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/ARE_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/HSY_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/WYNN_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/AIZ_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/L_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/OTIS_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/VZ_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/VRSK_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/K_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/CSCO_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/BRK-B_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/GE_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/MO_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/HST_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/ADI_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/IQV_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/ANET_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/BG_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/AXON_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/NFLX_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/BLK_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/RJF_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/TSN_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/CB_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/NTRS_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/BAX_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/BKR_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/DAY_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/FAST_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/NTAP_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/TGT_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/IBM_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/CTAS_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/BX_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/GNRC_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/EMN_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/OMC_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/KVUE_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/T_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/WEC_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/UBER_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/PTC_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/BBY_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/AAPL_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/DHR_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/EA_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/MCD_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/TAP_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/ZBH_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/CSX_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/CSGP_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/CFG_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/IP_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/KEY_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/AES_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/BLDR_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/INTU_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/KLAC_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/DLR_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/DD_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/AME_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/PFE_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/MHK_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/DASH_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/TJX_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/NI_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/PCG_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/BKNG_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/STLD_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/CAG_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/ABT_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/CDNS_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/FOX_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/KR_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/WY_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/CZR_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/HAS_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/FICO_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/BXP_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/TTWO_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/EFX_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/PG_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/CINF_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/ODFL_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/WFC_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/NWS_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/SLB_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/EPAM_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/J_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/PYPL_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/CEG_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/BSX_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/LIN_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/SNPS_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/WBD_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/UDR_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/GD_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/BA_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/PARA_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/MAA_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/AWK_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/LII_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/MPWR_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/PNR_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/MOS_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/HWM_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/HUBB_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/HAL_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/MDLZ_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/WAB_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/CNP_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/VLO_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/CPAY_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/AMD_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/INVH_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/DE_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/KMI_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/ADP_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/CMI_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/RCL_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/WMT_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/SNA_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/KKR_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/NEM_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/COR_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/ACN_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/NVDA_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/REGN_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/CARR_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/MLM_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/AFL_completo_arreglado.csv
# Archivo limpio guardado: ./datos_limpios/EG_completo_arreglado.csv
# Proceso completado. Archivos limpios guardados en: ./datos_limpios

# %%
import os
import pandas as pd

# --- Configuración ---
directorio = "./datos_limpios"  # Directorio con los archivos originales
archivo_referencia = "BX_completo_arreglado.csv"  # Archivo con las 111 columnas
directorio_salida = "./datos_normalizados"  # Directorio de salida

# Lista fija de columnas comunes
columnas_comunes = [
    "Date", "Total Liabilities Net Minority Interest", "Net Income From Continuing And Discontinued Operation",
    "Net Income Continuous Operations", "Share Issued", "Changes In Cash", "Total Debt", "Operating Revenue",
    "Net Income Common Stockholders", "Open", "Total Capitalization", "High", "Beginning Cash Position",
    "sectorKey", "Ordinary Shares Number", "Normalized Income", "Stockholders Equity", "Total Revenue",
    "Net Income Including Noncontrolling Interests", "Common Stock", "Low", "Net Income", "Diluted EPS",
    "Net Income From Continuing Operations", "Net Income From Continuing Operation Net Minority Interest",
    "Tangible Book Value", "Tax Effect Of Unusual Items", "Common Stock Equity", "Volume", "Pretax Income",
    "Cash And Cash Equivalents", "Basic Average Shares", "Long Term Debt And Capital Lease Obligation",
    "Investing Cash Flow", "End Cash Position", "Operating Cash Flow", "Close", "Total Assets", "Free Cash Flow",
    "Net Tangible Assets", "Total Equity Gross Minority Interest", "Basic EPS", "Capital Stock",
    "Diluted NI Availto Com Stockholders", "Financing Cash Flow", "Tax Rate For Calcs", "Diluted Average Shares",
    "Invested Capital"
]

# --- Crear directorio de salida si no existe ---
os.makedirs(directorio_salida, exist_ok=True)


# --- Función para normalizar los archivos ---
def normalizar_dataset(directorio, columnas_comunes, directorio_salida):
    archivos = [f for f in os.listdir(directorio) if f.endswith(".csv")]
    print(f"📂 Normalizando {len(archivos)} archivos...")

    for archivo in archivos:
        ruta_entrada = os.path.join(directorio, archivo)
        ruta_salida = os.path.join(directorio_salida, archivo)

        try:
            df = pd.read_csv(ruta_entrada)

            # Asegurar todas las columnas comunes
            for col in columnas_comunes:
                if col not in df.columns:
                    df[col] = 0  # Si falta, asigna 0

            # Mantener solo las columnas comunes y en el mismo orden
            df = df[columnas_comunes]

            df.to_csv(ruta_salida, index=False)
            print(f"✅ {archivo} normalizado y guardado")

        except Exception as e:
            print(f"⚠️ Error procesando {archivo}: {e}")


# --- Función para verificar consistencia ---
def verificar_consistencia(directorio):
    archivos = [f for f in os.listdir(directorio) if f.endswith(".csv")]
    columnas_base = None

    for archivo in archivos:
        df_temp = pd.read_csv(os.path.join(directorio, archivo), nrows=0)

        if columnas_base is None:
            columnas_base = set(df_temp.columns)
            print(f"🧩 Columnas base ({len(columnas_base)}): {sorted(columnas_base)}")
        else:
            columnas_actual = set(df_temp.columns)
            if columnas_base != columnas_actual:
                print(f"⚠️ {archivo} tiene columnas diferentes")
                print(f"Faltantes: {columnas_base - columnas_actual}")
                print(f"Adicionales: {columnas_actual - columnas_base}")

    print("✅ Verificación de consistencia completada")


# --- Ejecutar ---
normalizar_dataset(directorio, columnas_comunes, directorio_salida)
verificar_consistencia(directorio_salida)
# Out:
# 📂 Normalizando 502 archivos...
# ✅ GOOGL_completo_arreglado.csv normalizado y guardado
# ✅ SRE_completo_arreglado.csv normalizado y guardado
# ✅ STT_completo_arreglado.csv normalizado y guardado
# ✅ PGR_completo_arreglado.csv normalizado y guardado
# ✅ LEN_completo_arreglado.csv normalizado y guardado
# ✅ TDY_completo_arreglado.csv normalizado y guardado
# ✅ VRSN_completo_arreglado.csv normalizado y guardado
# ✅ IVZ_completo_arreglado.csv normalizado y guardado
# ✅ MTCH_completo_arreglado.csv normalizado y guardado
# ✅ SYK_completo_arreglado.csv normalizado y guardado
# ✅ SW_completo_arreglado.csv normalizado y guardado
# ✅ NXPI_completo_arreglado.csv normalizado y guardado
# ✅ RTX_completo_arreglado.csv normalizado y guardado
# ✅ EXC_completo_arreglado.csv normalizado y guardado
# ✅ CARR_completo_arreglado.csv normalizado y guardado
# ✅ ADBE_completo_arreglado.csv normalizado y guardado
# ✅ CCL_completo_arreglado.csv normalizado y guardado
# ✅ LYV_completo_arreglado.csv normalizado y guardado
# ✅ IT_completo_arreglado.csv normalizado y guardado
# ✅ DLR_completo_arreglado.csv normalizado y guardado
# ✅ POOL_completo_arreglado.csv normalizado y guardado
# ✅ IBM_completo_arreglado.csv normalizado y guardado
# ✅ FTV_completo_arreglado.csv normalizado y guardado
# ✅ VTR_completo_arreglado.csv normalizado y guardado
# ✅ NVDA_completo_arreglado.csv normalizado y guardado
# ✅ EQR_completo_arreglado.csv normalizado y guardado
# ✅ STLD_completo_arreglado.csv normalizado y guardado
# ✅ NUE_completo_arreglado.csv normalizado y guardado
# ✅ AEE_completo_arreglado.csv normalizado y guardado
# ✅ PNC_completo_arreglado.csv normalizado y guardado
# ✅ MMM_completo_arreglado.csv normalizado y guardado
# ✅ CPT_completo_arreglado.csv normalizado y guardado
# ✅ PEG_completo_arreglado.csv normalizado y guardado
# ✅ SLB_completo_arreglado.csv normalizado y guardado
# ✅ WY_completo_arreglado.csv normalizado y guardado
# ✅ COST_completo_arreglado.csv normalizado y guardado
# ✅ LULU_completo_arreglado.csv normalizado y guardado
# ✅ UNH_completo_arreglado.csv normalizado y guardado
# ✅ SCHW_completo_arreglado.csv normalizado y guardado
# ✅ APA_completo_arreglado.csv normalizado y guardado
# ✅ CI_completo_arreglado.csv normalizado y guardado
# ✅ INTU_completo_arreglado.csv normalizado y guardado
# ✅ BXP_completo_arreglado.csv normalizado y guardado
# ✅ SYF_completo_arreglado.csv normalizado y guardado
# ✅ NKE_completo_arreglado.csv normalizado y guardado
# ✅ MPWR_completo_arreglado.csv normalizado y guardado
# ✅ CSX_completo_arreglado.csv normalizado y guardado
# ✅ FITB_completo_arreglado.csv normalizado y guardado
# ✅ UDR_completo_arreglado.csv normalizado y guardado
# ✅ BBY_completo_arreglado.csv normalizado y guardado
# ✅ CRL_completo_arreglado.csv normalizado y guardado
# ✅ UHS_completo_arreglado.csv normalizado y guardado
# ✅ MTB_completo_arreglado.csv normalizado y guardado
# ✅ TRV_completo_arreglado.csv normalizado y guardado
# ✅ BMY_completo_arreglado.csv normalizado y guardado
# ✅ TECH_completo_arreglado.csv normalizado y guardado
# ✅ NRG_completo_arreglado.csv normalizado y guardado
# ✅ BAX_completo_arreglado.csv normalizado y guardado
# ✅ WRB_completo_arreglado.csv normalizado y guardado
# ✅ DASH_completo_arreglado.csv normalizado y guardado
# ✅ PCAR_completo_arreglado.csv normalizado y guardado
# ✅ ATO_completo_arreglado.csv normalizado y guardado
# ✅ MAA_completo_arreglado.csv normalizado y guardado
# ✅ ACGL_completo_arreglado.csv normalizado y guardado
# ✅ GM_completo_arreglado.csv normalizado y guardado
# ✅ CAT_completo_arreglado.csv normalizado y guardado
# ✅ TMO_completo_arreglado.csv normalizado y guardado
# ✅ JBHT_completo_arreglado.csv normalizado y guardado
# ✅ UBER_completo_arreglado.csv normalizado y guardado
# ✅ JCI_completo_arreglado.csv normalizado y guardado
# ✅ APH_completo_arreglado.csv normalizado y guardado
# ✅ DOW_completo_arreglado.csv normalizado y guardado
# ✅ TTD_completo_arreglado.csv normalizado y guardado
# ✅ BKNG_completo_arreglado.csv normalizado y guardado
# ✅ STZ_completo_arreglado.csv normalizado y guardado
# ✅ AVY_completo_arreglado.csv normalizado y guardado
# ✅ IP_completo_arreglado.csv normalizado y guardado
# ✅ CPRT_completo_arreglado.csv normalizado y guardado
# ✅ DE_completo_arreglado.csv normalizado y guardado
# ✅ HSIC_completo_arreglado.csv normalizado y guardado
# ✅ CHRW_completo_arreglado.csv normalizado y guardado
# ✅ HD_completo_arreglado.csv normalizado y guardado
# ✅ ROK_completo_arreglado.csv normalizado y guardado
# ✅ MRNA_completo_arreglado.csv normalizado y guardado
# ✅ DHR_completo_arreglado.csv normalizado y guardado
# ✅ AMD_completo_arreglado.csv normalizado y guardado
# ✅ PRU_completo_arreglado.csv normalizado y guardado
# ✅ EMN_completo_arreglado.csv normalizado y guardado
# ✅ HBAN_completo_arreglado.csv normalizado y guardado
# ✅ DGX_completo_arreglado.csv normalizado y guardado
# ✅ PSA_completo_arreglado.csv normalizado y guardado
# ✅ SBAC_completo_arreglado.csv normalizado y guardado
# ✅ KO_completo_arreglado.csv normalizado y guardado
# ✅ NCLH_completo_arreglado.csv normalizado y guardado
# ✅ GD_completo_arreglado.csv normalizado y guardado
# ✅ MMC_completo_arreglado.csv normalizado y guardado
# ✅ WDC_completo_arreglado.csv normalizado y guardado
# ✅ SPGI_completo_arreglado.csv normalizado y guardado
# ✅ APO_completo_arreglado.csv normalizado y guardado
# ✅ AAPL_completo_arreglado.csv normalizado y guardado
# ✅ NWS_completo_arreglado.csv normalizado y guardado
# ✅ WYNN_completo_arreglado.csv normalizado y guardado
# ✅ KEY_completo_arreglado.csv normalizado y guardado
# ✅ WAT_completo_arreglado.csv normalizado y guardado
# ✅ LOW_completo_arreglado.csv normalizado y guardado
# ✅ ROL_completo_arreglado.csv normalizado y guardado
# ✅ TRMB_completo_arreglado.csv normalizado y guardado
# ✅ ADSK_completo_arreglado.csv normalizado y guardado
# ✅ PPG_completo_arreglado.csv normalizado y guardado
# ✅ MSI_completo_arreglado.csv normalizado y guardado
# ✅ CNP_completo_arreglado.csv normalizado y guardado
# ✅ LHX_completo_arreglado.csv normalizado y guardado
# ✅ PFE_completo_arreglado.csv normalizado y guardado
# ✅ IQV_completo_arreglado.csv normalizado y guardado
# ✅ PTC_completo_arreglado.csv normalizado y guardado
# ✅ UAL_completo_arreglado.csv normalizado y guardado
# ✅ T_completo_arreglado.csv normalizado y guardado
# ✅ PAYX_completo_arreglado.csv normalizado y guardado
# ✅ AIG_completo_arreglado.csv normalizado y guardado
# ✅ FIS_completo_arreglado.csv normalizado y guardado
# ✅ MS_completo_arreglado.csv normalizado y guardado
# ✅ CBRE_completo_arreglado.csv normalizado y guardado
# ✅ VICI_completo_arreglado.csv normalizado y guardado
# ✅ OTIS_completo_arreglado.csv normalizado y guardado
# ✅ VST_completo_arreglado.csv normalizado y guardado
# ✅ WTW_completo_arreglado.csv normalizado y guardado
# ✅ TROW_completo_arreglado.csv normalizado y guardado
# ✅ ELV_completo_arreglado.csv normalizado y guardado
# ✅ KVUE_completo_arreglado.csv normalizado y guardado
# ✅ MPC_completo_arreglado.csv normalizado y guardado
# ✅ KLAC_completo_arreglado.csv normalizado y guardado
# ✅ XYZ_completo_arreglado.csv normalizado y guardado
# ✅ GRMN_completo_arreglado.csv normalizado y guardado
# ✅ TPL_completo_arreglado.csv normalizado y guardado
# ✅ HIG_completo_arreglado.csv normalizado y guardado
# ✅ LDOS_completo_arreglado.csv normalizado y guardado
# ✅ BX_completo_arreglado.csv normalizado y guardado
# ✅ SMCI_completo_arreglado.csv normalizado y guardado
# ✅ AJG_completo_arreglado.csv normalizado y guardado
# ✅ CL_completo_arreglado.csv normalizado y guardado
# ✅ BRK-B_completo_arreglado.csv normalizado y guardado
# ✅ APD_completo_arreglado.csv normalizado y guardado
# ✅ HPE_completo_arreglado.csv normalizado y guardado
# ✅ CF_completo_arreglado.csv normalizado y guardado
# ✅ AMCR_completo_arreglado.csv normalizado y guardado
# ✅ COO_completo_arreglado.csv normalizado y guardado
# ✅ EW_completo_arreglado.csv normalizado y guardado
# ✅ SBUX_completo_arreglado.csv normalizado y guardado
# ✅ ZBRA_completo_arreglado.csv normalizado y guardado
# ✅ BR_completo_arreglado.csv normalizado y guardado
# ✅ AWK_completo_arreglado.csv normalizado y guardado
# ✅ ROST_completo_arreglado.csv normalizado y guardado
# ✅ WMT_completo_arreglado.csv normalizado y guardado
# ✅ MDT_completo_arreglado.csv normalizado y guardado
# ✅ RCL_completo_arreglado.csv normalizado y guardado
# ✅ AFL_completo_arreglado.csv normalizado y guardado
# ✅ NTRS_completo_arreglado.csv normalizado y guardado
# ✅ BRO_completo_arreglado.csv normalizado y guardado
# ✅ PPL_completo_arreglado.csv normalizado y guardado
# ✅ WST_completo_arreglado.csv normalizado y guardado
# ✅ CBOE_completo_arreglado.csv normalizado y guardado
# ✅ GE_completo_arreglado.csv normalizado y guardado
# ✅ MU_completo_arreglado.csv normalizado y guardado
# ✅ EME_completo_arreglado.csv normalizado y guardado
# ✅ TFC_completo_arreglado.csv normalizado y guardado
# ✅ GIS_completo_arreglado.csv normalizado y guardado
# ✅ INVH_completo_arreglado.csv normalizado y guardado
# ✅ LVS_completo_arreglado.csv normalizado y guardado
# ✅ NOC_completo_arreglado.csv normalizado y guardado
# ✅ OXY_completo_arreglado.csv normalizado y guardado
# ✅ ERIE_completo_arreglado.csv normalizado y guardado
# ✅ BALL_completo_arreglado.csv normalizado y guardado
# ✅ IFF_completo_arreglado.csv normalizado y guardado
# ✅ NDSN_completo_arreglado.csv normalizado y guardado
# ✅ TXN_completo_arreglado.csv normalizado y guardado
# ✅ PYPL_completo_arreglado.csv normalizado y guardado
# ✅ RVTY_completo_arreglado.csv normalizado y guardado
# ✅ RL_completo_arreglado.csv normalizado y guardado
# ✅ GEHC_completo_arreglado.csv normalizado y guardado
# ✅ ULTA_completo_arreglado.csv normalizado y guardado
# ✅ CMCSA_completo_arreglado.csv normalizado y guardado
# ✅ AME_completo_arreglado.csv normalizado y guardado
# ✅ SOLV_completo_arreglado.csv normalizado y guardado
# ✅ CCI_completo_arreglado.csv normalizado y guardado
# ✅ RF_completo_arreglado.csv normalizado y guardado
# ✅ DOV_completo_arreglado.csv normalizado y guardado
# ✅ HWM_completo_arreglado.csv normalizado y guardado
# ✅ KEYS_completo_arreglado.csv normalizado y guardado
# ✅ DD_completo_arreglado.csv normalizado y guardado
# ✅ VRSK_completo_arreglado.csv normalizado y guardado
# ✅ LLY_completo_arreglado.csv normalizado y guardado
# ✅ PODD_completo_arreglado.csv normalizado y guardado
# ✅ GL_completo_arreglado.csv normalizado y guardado
# ✅ AOS_completo_arreglado.csv normalizado y guardado
# ✅ LH_completo_arreglado.csv normalizado y guardado
# ✅ CSCO_completo_arreglado.csv normalizado y guardado
# ✅ TGT_completo_arreglado.csv normalizado y guardado
# ✅ XEL_completo_arreglado.csv normalizado y guardado
# ✅ HII_completo_arreglado.csv normalizado y guardado
# ✅ EQT_completo_arreglado.csv normalizado y guardado
# ✅ CTSH_completo_arreglado.csv normalizado y guardado
# ✅ EXE_completo_arreglado.csv normalizado y guardado
# ✅ EQIX_completo_arreglado.csv normalizado y guardado
# ✅ DG_completo_arreglado.csv normalizado y guardado
# ✅ IR_completo_arreglado.csv normalizado y guardado
# ✅ HAL_completo_arreglado.csv normalizado y guardado
# ✅ CRM_completo_arreglado.csv normalizado y guardado
# ✅ TT_completo_arreglado.csv normalizado y guardado
# ✅ CB_completo_arreglado.csv normalizado y guardado
# ✅ GWW_completo_arreglado.csv normalizado y guardado
# ✅ STX_completo_arreglado.csv normalizado y guardado
# ✅ HOLX_completo_arreglado.csv normalizado y guardado
# ✅ ES_completo_arreglado.csv normalizado y guardado
# ✅ SWKS_completo_arreglado.csv normalizado y guardado
# ✅ FANG_completo_arreglado.csv normalizado y guardado
# ✅ MCHP_completo_arreglado.csv normalizado y guardado
# ✅ ZTS_completo_arreglado.csv normalizado y guardado
# ✅ KHC_completo_arreglado.csv normalizado y guardado
# ✅ AVGO_completo_arreglado.csv normalizado y guardado
# ✅ IPG_completo_arreglado.csv normalizado y guardado
# ✅ CHD_completo_arreglado.csv normalizado y guardado
# ✅ FFIV_completo_arreglado.csv normalizado y guardado
# ✅ LII_completo_arreglado.csv normalizado y guardado
# ✅ ETN_completo_arreglado.csv normalizado y guardado
# ✅ DAL_completo_arreglado.csv normalizado y guardado
# ✅ CMS_completo_arreglado.csv normalizado y guardado
# ✅ V_completo_arreglado.csv normalizado y guardado
# ✅ ADP_completo_arreglado.csv normalizado y guardado
# ✅ GEV_completo_arreglado.csv normalizado y guardado
# ✅ LKQ_completo_arreglado.csv normalizado y guardado
# ✅ ANET_completo_arreglado.csv normalizado y guardado
# ✅ ISRG_completo_arreglado.csv normalizado y guardado
# ✅ JKHY_completo_arreglado.csv normalizado y guardado
# ✅ BLK_completo_arreglado.csv normalizado y guardado
# ✅ TRGP_completo_arreglado.csv normalizado y guardado
# ✅ CINF_completo_arreglado.csv normalizado y guardado
# ✅ DTE_completo_arreglado.csv normalizado y guardado
# ✅ GILD_completo_arreglado.csv normalizado y guardado
# ✅ MTD_completo_arreglado.csv normalizado y guardado
# ✅ LUV_completo_arreglado.csv normalizado y guardado
# ✅ OKE_completo_arreglado.csv normalizado y guardado
# ✅ ORLY_completo_arreglado.csv normalizado y guardado
# ✅ USB_completo_arreglado.csv normalizado y guardado
# ✅ MOS_completo_arreglado.csv normalizado y guardado
# ✅ BSX_completo_arreglado.csv normalizado y guardado
# ✅ TEL_completo_arreglado.csv normalizado y guardado
# ✅ COF_completo_arreglado.csv normalizado y guardado
# ✅ ABBV_completo_arreglado.csv normalizado y guardado
# ✅ ON_completo_arreglado.csv normalizado y guardado
# ✅ PFG_completo_arreglado.csv normalizado y guardado
# ✅ TSN_completo_arreglado.csv normalizado y guardado
# ✅ HLT_completo_arreglado.csv normalizado y guardado
# ✅ VLO_completo_arreglado.csv normalizado y guardado
# ✅ LIN_completo_arreglado.csv normalizado y guardado
# ✅ J_completo_arreglado.csv normalizado y guardado
# ✅ NSC_completo_arreglado.csv normalizado y guardado
# ✅ CVX_completo_arreglado.csv normalizado y guardado
# ✅ PSX_completo_arreglado.csv normalizado y guardado
# ✅ XOM_completo_arreglado.csv normalizado y guardado
# ✅ AXON_completo_arreglado.csv normalizado y guardado
# ✅ KMB_completo_arreglado.csv normalizado y guardado
# ✅ PEP_completo_arreglado.csv normalizado y guardado
# ✅ FI_completo_arreglado.csv normalizado y guardado
# ✅ BKR_completo_arreglado.csv normalizado y guardado
# ✅ FDX_completo_arreglado.csv normalizado y guardado
# ✅ SPG_completo_arreglado.csv normalizado y guardado
# ✅ VZ_completo_arreglado.csv normalizado y guardado
# ✅ FTNT_completo_arreglado.csv normalizado y guardado
# ✅ CME_completo_arreglado.csv normalizado y guardado
# ✅ FOXA_completo_arreglado.csv normalizado y guardado
# ✅ DECK_completo_arreglado.csv normalizado y guardado
# ✅ META_completo_arreglado.csv normalizado y guardado
# ✅ WELL_completo_arreglado.csv normalizado y guardado
# ✅ COP_completo_arreglado.csv normalizado y guardado
# ✅ PLTR_completo_arreglado.csv normalizado y guardado
# ✅ BDX_completo_arreglado.csv normalizado y guardado
# ✅ MCD_completo_arreglado.csv normalizado y guardado
# ✅ GPC_completo_arreglado.csv normalizado y guardado
# ✅ INCY_completo_arreglado.csv normalizado y guardado
# ✅ CSGP_completo_arreglado.csv normalizado y guardado
# ✅ BG_completo_arreglado.csv normalizado y guardado
# ✅ EPAM_completo_arreglado.csv normalizado y guardado
# ✅ HON_completo_arreglado.csv normalizado y guardado
# ✅ PANW_completo_arreglado.csv normalizado y guardado
# ✅ ACN_completo_arreglado.csv normalizado y guardado
# ✅ DVA_completo_arreglado.csv normalizado y guardado
# ✅ NWSA_completo_arreglado.csv normalizado y guardado
# ✅ HUM_completo_arreglado.csv normalizado y guardado
# ✅ IEX_completo_arreglado.csv normalizado y guardado
# ✅ WEC_completo_arreglado.csv normalizado y guardado
# ✅ AKAM_completo_arreglado.csv normalizado y guardado
# ✅ MGM_completo_arreglado.csv normalizado y guardado
# ✅ AMGN_completo_arreglado.csv normalizado y guardado
# ✅ QCOM_completo_arreglado.csv normalizado y guardado
# ✅ DELL_completo_arreglado.csv normalizado y guardado
# ✅ DPZ_completo_arreglado.csv normalizado y guardado
# ✅ GPN_completo_arreglado.csv normalizado y guardado
# ✅ CNC_completo_arreglado.csv normalizado y guardado
# ✅ REGN_completo_arreglado.csv normalizado y guardado
# ✅ AMP_completo_arreglado.csv normalizado y guardado
# ✅ MOH_completo_arreglado.csv normalizado y guardado
# ✅ RSG_completo_arreglado.csv normalizado y guardado
# ✅ CEG_completo_arreglado.csv normalizado y guardado
# ✅ FSLR_completo_arreglado.csv normalizado y guardado
# ✅ DOC_completo_arreglado.csv normalizado y guardado
# ✅ ETR_completo_arreglado.csv normalizado y guardado
# ✅ CHTR_completo_arreglado.csv normalizado y guardado
# ✅ EVRG_completo_arreglado.csv normalizado y guardado
# ✅ D_completo_arreglado.csv normalizado y guardado
# ✅ RJF_completo_arreglado.csv normalizado y guardado
# ✅ AXP_completo_arreglado.csv normalizado y guardado
# ✅ BF-B_completo_arreglado.csv normalizado y guardado
# ✅ FOX_completo_arreglado.csv normalizado y guardado
# ✅ EXPD_completo_arreglado.csv normalizado y guardado
# ✅ GEN_completo_arreglado.csv normalizado y guardado
# ✅ TMUS_completo_arreglado.csv normalizado y guardado
# ✅ LW_completo_arreglado.csv normalizado y guardado
# ✅ NEE_completo_arreglado.csv normalizado y guardado
# ✅ NTAP_completo_arreglado.csv normalizado y guardado
# ✅ IRM_completo_arreglado.csv normalizado y guardado
# ✅ GS_completo_arreglado.csv normalizado y guardado
# ✅ TAP_completo_arreglado.csv normalizado y guardado
# ✅ KR_completo_arreglado.csv normalizado y guardado
# ✅ ALLE_completo_arreglado.csv normalizado y guardado
# ✅ FRT_completo_arreglado.csv normalizado y guardado
# ✅ DLTR_completo_arreglado.csv normalizado y guardado
# ✅ FAST_completo_arreglado.csv normalizado y guardado
# ✅ AZO_completo_arreglado.csv normalizado y guardado
# ✅ VMC_completo_arreglado.csv normalizado y guardado
# ✅ VRTX_completo_arreglado.csv normalizado y guardado
# ✅ EL_completo_arreglado.csv normalizado y guardado
# ✅ PWR_completo_arreglado.csv normalizado y guardado
# ✅ HAS_completo_arreglado.csv normalizado y guardado
# ✅ HUBB_completo_arreglado.csv normalizado y guardado
# ✅ TYL_completo_arreglado.csv normalizado y guardado
# ✅ C_completo_arreglado.csv normalizado y guardado
# ✅ CAG_completo_arreglado.csv normalizado y guardado
# ✅ PH_completo_arreglado.csv normalizado y guardado
# ✅ PNW_completo_arreglado.csv normalizado y guardado
# ✅ HCA_completo_arreglado.csv normalizado y guardado
# ✅ DAY_completo_arreglado.csv normalizado y guardado
# ✅ MNST_completo_arreglado.csv normalizado y guardado
# ✅ LRCX_completo_arreglado.csv normalizado y guardado
# ✅ MLM_completo_arreglado.csv normalizado y guardado
# ✅ RMD_completo_arreglado.csv normalizado y guardado
# ✅ WM_completo_arreglado.csv normalizado y guardado
# ✅ ABT_completo_arreglado.csv normalizado y guardado
# ✅ SWK_completo_arreglado.csv normalizado y guardado
# ✅ CLX_completo_arreglado.csv normalizado y guardado
# ✅ XYL_completo_arreglado.csv normalizado y guardado
# ✅ ORCL_completo_arreglado.csv normalizado y guardado
# ✅ SJM_completo_arreglado.csv normalizado y guardado
# ✅ HRL_completo_arreglado.csv normalizado y guardado
# ✅ DXCM_completo_arreglado.csv normalizado y guardado
# ✅ AIZ_completo_arreglado.csv normalizado y guardado
# ✅ IDXX_completo_arreglado.csv normalizado y guardado
# ✅ MAR_completo_arreglado.csv normalizado y guardado
# ✅ IBKR_completo_arreglado.csv normalizado y guardado
# ✅ TDG_completo_arreglado.csv normalizado y guardado
# ✅ WMB_completo_arreglado.csv normalizado y guardado
# ✅ COIN_completo_arreglado.csv normalizado y guardado
# ✅ SNPS_completo_arreglado.csv normalizado y guardado
# ✅ EA_completo_arreglado.csv normalizado y guardado
# ✅ ESS_completo_arreglado.csv normalizado y guardado
# ✅ LYB_completo_arreglado.csv normalizado y guardado
# ✅ LNT_completo_arreglado.csv normalizado y guardado
# ✅ ABNB_completo_arreglado.csv normalizado y guardado
# ✅ KDP_completo_arreglado.csv normalizado y guardado
# ✅ AMT_completo_arreglado.csv normalizado y guardado
# ✅ URI_completo_arreglado.csv normalizado y guardado
# ✅ PKG_completo_arreglado.csv normalizado y guardado
# ✅ CDW_completo_arreglado.csv normalizado y guardado
# ✅ VLTO_completo_arreglado.csv normalizado y guardado
# ✅ COR_completo_arreglado.csv normalizado y guardado
# ✅ AVB_completo_arreglado.csv normalizado y guardado
# ✅ MRK_completo_arreglado.csv normalizado y guardado
# ✅ BLDR_completo_arreglado.csv normalizado y guardado
# ✅ DHI_completo_arreglado.csv normalizado y guardado
# ✅ CTVA_completo_arreglado.csv normalizado y guardado
# ✅ ROP_completo_arreglado.csv normalizado y guardado
# ✅ MSCI_completo_arreglado.csv normalizado y guardado
# ✅ ZBH_completo_arreglado.csv normalizado y guardado
# ✅ JBL_completo_arreglado.csv normalizado y guardado
# ✅ BEN_completo_arreglado.csv normalizado y guardado
# ✅ WAB_completo_arreglado.csv normalizado y guardado
# ✅ TTWO_completo_arreglado.csv normalizado y guardado
# ✅ TER_completo_arreglado.csv normalizado y guardado
# ✅ TXT_completo_arreglado.csv normalizado y guardado
# ✅ UNP_completo_arreglado.csv normalizado y guardado
# ✅ LMT_completo_arreglado.csv normalizado y guardado
# ✅ HSY_completo_arreglado.csv normalizado y guardado
# ✅ MKC_completo_arreglado.csv normalizado y guardado
# ✅ MAS_completo_arreglado.csv normalizado y guardado
# ✅ PHM_completo_arreglado.csv normalizado y guardado
# ✅ CMG_completo_arreglado.csv normalizado y guardado
# ✅ CDNS_completo_arreglado.csv normalizado y guardado
# ✅ DVN_completo_arreglado.csv normalizado y guardado
# ✅ MO_completo_arreglado.csv normalizado y guardado
# ✅ AEP_completo_arreglado.csv normalizado y guardado
# ✅ APTV_completo_arreglado.csv normalizado y guardado
# ✅ GNRC_completo_arreglado.csv normalizado y guardado
# ✅ TJX_completo_arreglado.csv normalizado y guardado
# ✅ MCK_completo_arreglado.csv normalizado y guardado
# ✅ PLD_completo_arreglado.csv normalizado y guardado
# ✅ NFLX_completo_arreglado.csv normalizado y guardado
# ✅ REG_completo_arreglado.csv normalizado y guardado
# ✅ ODFL_completo_arreglado.csv normalizado y guardado
# ✅ ECL_completo_arreglado.csv normalizado y guardado
# ✅ NI_completo_arreglado.csv normalizado y guardado
# ✅ SO_completo_arreglado.csv normalizado y guardado
# ✅ JNJ_completo_arreglado.csv normalizado y guardado
# ✅ EOG_completo_arreglado.csv normalizado y guardado
# ✅ TSLA_completo_arreglado.csv normalizado y guardado
# ✅ ALL_completo_arreglado.csv normalizado y guardado
# ✅ SYY_completo_arreglado.csv normalizado y guardado
# ✅ GDDY_completo_arreglado.csv normalizado y guardado
# ✅ EBAY_completo_arreglado.csv normalizado y guardado
# ✅ EG_completo_arreglado.csv normalizado y guardado
# ✅ EMR_completo_arreglado.csv normalizado y guardado
# ✅ ADI_completo_arreglado.csv normalizado y guardado
# ✅ YUM_completo_arreglado.csv normalizado y guardado
# ✅ PAYC_completo_arreglado.csv normalizado y guardado
# ✅ JPM_completo_arreglado.csv normalizado y guardado
# ✅ O_completo_arreglado.csv normalizado y guardado
# ✅ MSFT_completo_arreglado.csv normalizado y guardado
# ✅ WBD_completo_arreglado.csv normalizado y guardado
# ✅ FCX_completo_arreglado.csv normalizado y guardado
# ✅ EXPE_completo_arreglado.csv normalizado y guardado
# ✅ PSKY_completo_arreglado.csv normalizado y guardado
# ✅ HST_completo_arreglado.csv normalizado y guardado
# ✅ ITW_completo_arreglado.csv normalizado y guardado
# ✅ WFC_completo_arreglado.csv normalizado y guardado
# ✅ DIS_completo_arreglado.csv normalizado y guardado
# ✅ ED_completo_arreglado.csv normalizado y guardado
# ✅ GLW_completo_arreglado.csv normalizado y guardado
# ✅ EXR_completo_arreglado.csv normalizado y guardado
# ✅ BA_completo_arreglado.csv normalizado y guardado
# ✅ VTRS_completo_arreglado.csv normalizado y guardado
# ✅ SHW_completo_arreglado.csv normalizado y guardado
# ✅ DUK_completo_arreglado.csv normalizado y guardado
# ✅ CTAS_completo_arreglado.csv normalizado y guardado
# ✅ BK_completo_arreglado.csv normalizado y guardado
# ✅ INTC_completo_arreglado.csv normalizado y guardado
# ✅ STE_completo_arreglado.csv normalizado y guardado
# ✅ WDAY_completo_arreglado.csv normalizado y guardado
# ✅ CFG_completo_arreglado.csv normalizado y guardado
# ✅ PCG_completo_arreglado.csv normalizado y guardado
# ✅ NEM_completo_arreglado.csv normalizado y guardado
# ✅ HOOD_completo_arreglado.csv normalizado y guardado
# ✅ CTRA_completo_arreglado.csv normalizado y guardado
# ✅ GOOG_completo_arreglado.csv normalizado y guardado
# ✅ PM_completo_arreglado.csv normalizado y guardado
# ✅ PNR_completo_arreglado.csv normalizado y guardado
# ✅ F_completo_arreglado.csv normalizado y guardado
# ✅ CPAY_completo_arreglado.csv normalizado y guardado
# ✅ AMAT_completo_arreglado.csv normalizado y guardado
# ✅ CMI_completo_arreglado.csv normalizado y guardado
# ✅ MA_completo_arreglado.csv normalizado y guardado
# ✅ L_completo_arreglado.csv normalizado y guardado
# ✅ AON_completo_arreglado.csv normalizado y guardado
# ✅ CAH_completo_arreglado.csv normalizado y guardado
# ✅ PG_completo_arreglado.csv normalizado y guardado
# ✅ NOW_completo_arreglado.csv normalizado y guardado
# ✅ FE_completo_arreglado.csv normalizado y guardado
# ✅ UPS_completo_arreglado.csv normalizado y guardado
# ✅ DDOG_completo_arreglado.csv normalizado y guardado
# ✅ OMC_completo_arreglado.csv normalizado y guardado
# ✅ MET_completo_arreglado.csv normalizado y guardado
# ✅ CRWD_completo_arreglado.csv normalizado y guardado
# ✅ NVR_completo_arreglado.csv normalizado y guardado
# ✅ KIM_completo_arreglado.csv normalizado y guardado
# ✅ MHK_completo_arreglado.csv normalizado y guardado
# ✅ EIX_completo_arreglado.csv normalizado y guardado
# ✅ ALB_completo_arreglado.csv normalizado y guardado
# ✅ SNA_completo_arreglado.csv normalizado y guardado
# ✅ MCO_completo_arreglado.csv normalizado y guardado
# ✅ DRI_completo_arreglado.csv normalizado y guardado
# ✅ HPQ_completo_arreglado.csv normalizado y guardado
# ✅ APP_completo_arreglado.csv normalizado y guardado
# ✅ FICO_completo_arreglado.csv normalizado y guardado
# ✅ ALGN_completo_arreglado.csv normalizado y guardado
# ✅ KKR_completo_arreglado.csv normalizado y guardado
# ✅ BAC_completo_arreglado.csv normalizado y guardado
# ✅ ICE_completo_arreglado.csv normalizado y guardado
# ✅ TSCO_completo_arreglado.csv normalizado y guardado
# ✅ CPB_completo_arreglado.csv normalizado y guardado
# ✅ WSM_completo_arreglado.csv normalizado y guardado
# ✅ EFX_completo_arreglado.csv normalizado y guardado
# ✅ AES_completo_arreglado.csv normalizado y guardado
# ✅ ARE_completo_arreglado.csv normalizado y guardado
# ✅ A_completo_arreglado.csv normalizado y guardado
# ✅ AMZN_completo_arreglado.csv normalizado y guardado
# ✅ TKO_completo_arreglado.csv normalizado y guardado
# ✅ CVS_completo_arreglado.csv normalizado y guardado
# ✅ TPR_completo_arreglado.csv normalizado y guardado
# ✅ K_completo_arreglado.csv normalizado y guardado
# ✅ MDLZ_completo_arreglado.csv normalizado y guardado
# ✅ BIIB_completo_arreglado.csv normalizado y guardado
# ✅ FDS_completo_arreglado.csv normalizado y guardado
# ✅ ADM_completo_arreglado.csv normalizado y guardado
# ✅ KMI_completo_arreglado.csv normalizado y guardado
# ✅ NDAQ_completo_arreglado.csv normalizado y guardado
# 🧩 Columnas base (48): ['Basic Average Shares', 'Basic EPS', 'Beginning Cash Position', 'Capital Stock', 'Cash And Cash Equivalents', 'Changes In Cash', 'Close', 'Common Stock', 'Common Stock Equity', 'Date', 'Diluted Average Shares', 'Diluted EPS', 'Diluted NI Availto Com Stockholders', 'End Cash Position', 'Financing Cash Flow', 'Free Cash Flow', 'High', 'Invested Capital', 'Investing Cash Flow', 'Long Term Debt And Capital Lease Obligation', 'Low', 'Net Income', 'Net Income Common Stockholders', 'Net Income Continuous Operations', 'Net Income From Continuing And Discontinued Operation', 'Net Income From Continuing Operation Net Minority Interest', 'Net Income From Continuing Operations', 'Net Income Including Noncontrolling Interests', 'Net Tangible Assets', 'Normalized Income', 'Open', 'Operating Cash Flow', 'Operating Revenue', 'Ordinary Shares Number', 'Pretax Income', 'Share Issued', 'Stockholders Equity', 'Tangible Book Value', 'Tax Effect Of Unusual Items', 'Tax Rate For Calcs', 'Total Assets', 'Total Capitalization', 'Total Debt', 'Total Equity Gross Minority Interest', 'Total Liabilities Net Minority Interest', 'Total Revenue', 'Volume', 'sectorKey']
# ✅ Verificación de consistencia completada

# %%
# Verificar que todos los archivos tengan las mismas columnas
def verificar_consistencia(directorio):
    """
    Verifica que todos los archivos en el directorio tengan las mismas columnas.
    """
    archivos = [f for f in os.listdir(directorio) if f.endswith('.csv')]
    columnas_base = None
    
    for archivo in archivos:
        df_temp = pd.read_csv(os.path.join(directorio, archivo), nrows=0)
        
        if columnas_base is None:
            columnas_base = set(df_temp.columns)
            print(f"Columnas base ({len(columnas_base)}): {sorted(columnas_base)}")
        else:
            columnas_actual = set(df_temp.columns)
            if columnas_base != columnas_actual:
                print(f"Advertencia: {archivo} tiene columnas diferentes")
                print(f"Faltantes: {columnas_base - columnas_actual}")
                print(f"Adicionales: {columnas_actual - columnas_base}")
    
    print("Verificación de consistencia completada")

# Verificar consistencia
verificar_consistencia(directorio_salida)
# Out:
# Columnas base (48): ['Basic Average Shares', 'Basic EPS', 'Beginning Cash Position', 'Capital Stock', 'Cash And Cash Equivalents', 'Changes In Cash', 'Close', 'Common Stock', 'Common Stock Equity', 'Date', 'Diluted Average Shares', 'Diluted EPS', 'Diluted NI Availto Com Stockholders', 'End Cash Position', 'Financing Cash Flow', 'Free Cash Flow', 'High', 'Invested Capital', 'Investing Cash Flow', 'Long Term Debt And Capital Lease Obligation', 'Low', 'Net Income', 'Net Income Common Stockholders', 'Net Income Continuous Operations', 'Net Income From Continuing And Discontinued Operation', 'Net Income From Continuing Operation Net Minority Interest', 'Net Income From Continuing Operations', 'Net Income Including Noncontrolling Interests', 'Net Tangible Assets', 'Normalized Income', 'Open', 'Operating Cash Flow', 'Operating Revenue', 'Ordinary Shares Number', 'Pretax Income', 'Share Issued', 'Stockholders Equity', 'Tangible Book Value', 'Tax Effect Of Unusual Items', 'Tax Rate For Calcs', 'Total Assets', 'Total Capitalization', 'Total Debt', 'Total Equity Gross Minority Interest', 'Total Liabilities Net Minority Interest', 'Total Revenue', 'Volume', 'sectorKey']
# Verificación de consistencia completada

# %%
 # !pip install TA-Lib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: TA-Lib in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (0.6.7)
# Requirement already satisfied: build in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from TA-Lib) (1.3.0)
# Requirement already satisfied: cython in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from TA-Lib) (3.1.3)
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from TA-Lib) (1.26.4)
# Requirement already satisfied: packaging>=19.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from build->TA-Lib) (25.0)
# Requirement already satisfied: pyproject_hooks in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from build->TA-Lib) (1.2.0)
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd
import glob

def obtener_sectores_unicos(path_pattern="data/*.csv", col_sector="sectorKey"):
    """
    Lee múltiples CSV y devuelve una lista de todos los sectores únicos.
    
    Args:
        path_pattern (str): patrón de búsqueda para archivos CSV (ej: 'data/*.csv')
        col_sector (str): nombre de la columna que contiene el sector
    
    Returns:
        list: lista de sectores únicos encontrados en todos los archivos
    """
    sectores = set()
    
    # Buscar todos los CSV en la ruta indicada
    for file in glob.glob(path_pattern):
        df = pd.read_csv(file)
        if col_sector in df.columns:
            sectores.update(df[col_sector].dropna().unique())
    
    return sorted(list(sectores))

# Ejemplo de uso
sectores_totales = obtener_sectores_unicos("./datos_normalizados/*.csv", col_sector="sectorKey")
print("Sectores encontrados:", sectores_totales)
# Out:
# Sectores encontrados: ['basic-materials', 'communication-services', 'consumer-cyclical', 'consumer-defensive', 'energy', 'financial-services', 'healthcare', 'industrials', 'real-estate', 'technology', 'utilities']

# %%
len(sectores_totales)
# Out:
# 11

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.model_selection import train_test_split
import joblib
import talib as ta


def calculate_technical_indicators(df):
    """Calcula 48 indicadores técnicos y agrega datos financieros"""
    # Precios
    open_price = df['Open'].values
    high = df['High'].values
    low = df['Low'].values
    close = df['Close'].values
    volume = df['Volume'].values
    
    features = {}
    
    # ===== INDICADORES TÉCNICOS (48 features) =====
    
    # Medias móviles (8 features)
    features['SMA_5'] = ta.SMA(close, timeperiod=5)
    features['SMA_10'] = ta.SMA(close, timeperiod=10)
    features['SMA_20'] = ta.SMA(close, timeperiod=20)
    features['SMA_50'] = ta.SMA(close, timeperiod=50)
    features['EMA_5'] = ta.EMA(close, timeperiod=5)
    features['EMA_10'] = ta.EMA(close, timeperiod=10)
    features['EMA_20'] = ta.EMA(close, timeperiod=20)
    features['EMA_50'] = ta.EMA(close, timeperiod=50)
    
    # Osciladores (12 features)
    features['RSI'] = ta.RSI(close)
    features['STOCH_K'], features['STOCH_D'] = ta.STOCH(high, low, close)
    features['MACD'], features['MACD_Signal'], features['MACD_Hist'] = ta.MACD(close)
    features['ADX'] = ta.ADX(high, low, close)
    features['CCI'] = ta.CCI(high, low, close)
    features['WILLR'] = ta.WILLR(high, low, close)
    features['ULTOSC'] = ta.ULTOSC(high, low, close)
    features['ROC'] = ta.ROC(close)
    
    # Volatilidad (6 features)
    features['ATR'] = ta.ATR(high, low, close)
    features['NATR'] = ta.NATR(high, low, close)
    features['TRANGE'] = ta.TRANGE(high, low, close)
    features['BB_Upper'], features['BB_Middle'], features['BB_Lower'] = ta.BBANDS(close)
    
    # Volumen (5 features)
    # features['OBV'] = ta.OBV(close, volume)
    # features['AD'] = ta.AD(high, low, close, volume)
    # features['ADOSC'] = ta.ADOSC(high, low, close, volume)
    # features['MFI'] = ta.MFI(high, low, close, volume)
    
    # Momentum (8 features)
    features['MOM'] = ta.MOM(close)
    features['PPO'] = ta.PPO(close)
    features['APO'] = ta.APO(close)
    features['AROON_Up'], features['AROON_Down'] = ta.AROON(high, low)
    features['AROONOSC'] = ta.AROONOSC(high, low)
    features['BOP'] = ta.BOP(open_price, high, low, close)
    
    # Precios relativos (9 features)
    features['Price_Change'] = close / np.roll(close, 1) - 1
    features['High_Low_Ratio'] = high / low
    features['Close_Open_Ratio'] = close / open_price
    # features['Volume_Change'] = volume / np.roll(volume, 1) - 1
    

    # ===== RATIOS FINANCIEROS DERIVADOS =====
    with np.errstate(divide='ignore', invalid='ignore'):
        features['ROE'] = df['Net Income'] / df['Total Equity Gross Minority Interest']
        features['ROA'] = df['Net Income'] / df['Total Assets']
        features['Debt_to_Equity'] = df['Total Debt'] / df['Total Equity Gross Minority Interest']
        features['Profit_Margin'] = df['Net Income'] / df['Total Revenue']
        features['Operating_Margin'] = df['Operating Revenue'] / df['Total Revenue']
        features['Asset_Turnover'] = df['Total Revenue'] / df['Total Assets']
        features['Financial_Leverage'] = df['Total Assets'] / df['Common Stock Equity']
        features['EPS_Calc'] = df['Net Income'] / df['Diluted Average Shares']



    # ===== DATOS FINANCIeros DEL CSV (46 features adicionales) Comparado con el CLOSE=====
    


    # Flujo de caja y liquidez
    features['Free_Cash_Flow'] = df['Free Cash Flow']/close
    features['Operating_Cash_Flow'] = df['Operating Cash Flow']/close
    features['Investing_Cash_Flow'] = df['Investing Cash Flow']/close
    features['Financing_Cash_Flow'] = df['Financing Cash Flow']/close
    features['Beginning_Cash_Position'] = df['Beginning Cash Position']/close
    features['End_Cash_Position'] = df['End Cash Position']/close
    features['Changes_In_Cash'] = df['Changes In Cash']/close
    features['Cash_And_Cash_Equivalents'] = df['Cash And Cash Equivalents']/close
    
    # Rentabilidad
    features['Net_Income'] = df['Net Income']/close
    features['Pretax_Income'] = df['Pretax Income']/close
    features['Total_Revenue'] = df['Total Revenue']/close
    features['Operating_Revenue'] = df['Operating Revenue']/close
    features['Normalized_Income'] = df['Normalized Income']/close
    features['Net_Income_Common_Stockholders'] = df['Net Income Common Stockholders']/close
    features['Net_Income_From_Continuing_Operations'] = df['Net Income From Continuing Operations']/close
    features['Net_Income_From_Continuing_And_Discontinued_Operation'] = df['Net Income From Continuing And Discontinued Operation']/close
    features['Net_Income_Including_Noncontrolling_Interests'] = df['Net Income Including Noncontrolling Interests']/close
    features['Net_Income_Continuous_Operations'] = df['Net Income Continuous Operations']/close
    features['Diluted_NI_Availto_Com_Stockholders'] = df['Diluted NI Availto Com Stockholders']/close
    features['Net_Income_From_Continuing_Operation_Net_Minority_Interest'] = df['Net Income From Continuing Operation Net Minority Interest']/close
    
    # Por acción
    features['Basic_EPS'] = df['Basic EPS']/close
    features['Diluted_EPS'] = df['Diluted EPS']/close
    
    # Acciones
    features['Diluted_Average_Shares'] = df['Diluted Average Shares']/close
    features['Basic_Average_Shares'] = df['Basic Average Shares']/close
    features['Share_Issued'] = df['Share Issued']/close
    features['Ordinary_Shares_Number'] = df['Ordinary Shares Number']/close
    features['Capital_Stock'] = df['Capital Stock']/close
    features['Common_Stock'] = df['Common Stock']/close
    
    # Balance general
    features['Total_Assets'] = df['Total Assets']/close
    features['Total_Liabilities_Net_Minority_Interest'] = df['Total Liabilities Net Minority Interest']/close
    features['Total_Equity_Gross_Minority_Interest'] = df['Total Equity Gross Minority Interest']/close
    features['Common_Stock_Equity'] = df['Common Stock Equity']/close
    features['Stockholders_Equity'] = df['Stockholders Equity']/close
    features['Total_Capitalization'] = df['Total Capitalization']/close
    features['Invested_Capital'] = df['Invested Capital']/close
    features['Net_Tangible_Assets'] = df['Net Tangible Assets']/close
    features['Tangible_Book_Value'] = df['Tangible Book Value']/close
    
    # Deuda
    features['Total_Debt'] = df['Total Debt']/close
    features['Long_Term_Debt_And_Capital_Lease_Obligation'] = df['Long Term Debt And Capital Lease Obligation']/close
    
    # Ratios financieros
    features['Tax_Rate_For_Calcs'] = df['Tax Rate For Calcs']/close
    features['Tax_Effect_Of_Unusual_Items'] = df['Tax Effect Of Unusual Items']/close
    features['Close'] = df['Close']
    features['Date'] = df['Date']
    
    # Sector (convertir a numérico si es necesario)
    # if 'sectorKey' in df.columns:
    #     # One-hot encoding para sector
    #     sector_dummies = pd.get_dummies(df['sectorKey'], prefix='Sector')
    #     for col in sector_dummies.columns:
    #         features[col] = sector_dummies[col]
    if 'sectorKey' in df.columns:
        # Generar one-hot encoding SOLO de los sectores presentes en este df
        sector_dummies = pd.get_dummies(df['sectorKey'], prefix='Sector')

        # Crear todas las columnas esperadas en base a sectores_totales
        expected_cols = [f"Sector_{s}" for s in sectores_totales]

        # Reindexar para incluir todos los sectores, rellenando con 0 donde falten
        sector_dummies = sector_dummies.reindex(columns=expected_cols, fill_value=0)

        # Convertir booleanos a enteros (0 o 1)
        sector_dummies = sector_dummies.astype(int)

        # Agregar cada columna dummy al diccionario de features
        for col in sector_dummies.columns:
            features[col] = sector_dummies[col]  
    
    # Convertir a DataFrame
    features_df = pd.DataFrame(features, index=df.index)
    
    # Eliminar columnas que puedan tener todos valores NaN
    features_df = features_df.dropna(axis=1, how='all')
    
    # Llenar valores NaN restantes con 0 o método apropiado
    features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
    
    return features_df

# %%
def create_target_variable(df, horizon):
    """Crea la variable objetivo: % cambio en los próximos 3 meses (63 días trading)"""
    # Asegurarse de que los datos están ordenados por fecha
    df = df.sort_index()
    
    # Calcular precio futuro (3 meses después)
    future_prices = df['Close'].shift(-horizon)
    current_prices = df['Close']
    
    # Calcular porcentaje de cambio
    target = ((future_prices - current_prices) / current_prices) * 100
    
    # Crear DataFrame con target
    target_df = pd.DataFrame({
        'Target_3M_Return': target,
        'Target_Direction': np.where(target > 0, 1, 0)  # 1: subida, 0: bajada
    }, index=df.index)
    df_with_target = df.join(target_df, how='left')
    
    # Eliminar valores donde no hay futuro disponible
    df_with_target = df_with_target.dropna()
    
    return df_with_target

# %%
def data_augmentation_dataset(directorio, directorio_salida=None):
    """
    Normaliza todos los archivos CSV en el directorio manteniendo solo las columnas comunes.
    """
    if directorio_salida is None:
        directorio_salida = directorio
    
    # Crear directorio de salida si no existe
    if not os.path.exists(directorio_salida):
        os.makedirs(directorio_salida)
    
    # Listar todos los archivos CSV en el directorio
    archivos = [f for f in os.listdir(directorio) if f.endswith('.csv')]
    # archivos = ["A_completo_arreglado.csv"]
    
    for archivo in archivos:
        try:
            # Leer el archivo
            df = pd.read_csv(os.path.join(directorio, archivo))
            df_2 = calculate_technical_indicators(df=df)
            df_3 = create_target_variable(df=df_2, horizon= 60)

            # Guardar el archivo normalizado
            ruta_salida = os.path.join(directorio_salida, archivo)
            df_3.to_csv(ruta_salida, index=False)
            
        except Exception as e:
            print(f"Error procesando {archivo}: {str(e)}")
            continue

# %%
import os
import shutil

# Configuración
directorio = "./datos_normalizados"  # Cambia esto por tu directorio
directorio_salida = "./data_final_v3"  # Directorio para archivos normalizados

# Encontrar columnas comunes
data_augmentation_dataset(directorio, directorio_salida)
# Out:
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# ...
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)

# %%
def create_target_variable_v2(df, horizon):
    """Crea la variable objetivo: % cambio en los próximos 3 meses (63 días trading)"""
    # Asegurarse de que los datos están ordenados por fecha
    df = df.sort_index()
    
    # Calcular precio futuro (3 meses después)
    future_prices = df['Close'].shift(-horizon)
    current_prices = df['Close']
    
    # Calcular porcentaje de cambio
    target = ((future_prices - current_prices) / current_prices) * 100
    
    # Crear DataFrame con target
    target_df = pd.DataFrame({
        'Target_3M_Return': target,
        'Target_Direction': np.where(target > 0, 1, 0)  # 1: subida, 0: bajada
    }, index=df.index)
    df_with_target = df.join(target_df, how='left')
    
    # Eliminar valores donde no hay futuro disponible
    # df_with_target = df_with_target.dropna()
    
    return df_with_target

# %%
def data_augmentation_dataset_with_unknow_values(directorio, directorio_salida=None):
    """
    Normaliza todos los archivos CSV en el directorio manteniendo solo las columnas comunes.
    """
    if directorio_salida is None:
        directorio_salida = directorio
    
    # Crear directorio de salida si no existe
    if not os.path.exists(directorio_salida):
        os.makedirs(directorio_salida)
    
    # Listar todos los archivos CSV en el directorio
    archivos = [f for f in os.listdir(directorio) if f.endswith('.csv')]
    # archivos = ["A_completo_arreglado.csv"]
    
    for archivo in archivos:
        try:
            # Leer el archivo
            df = pd.read_csv(os.path.join(directorio, archivo))
            df_2 = calculate_technical_indicators(df=df)
            df_3 = create_target_variable_v2(df=df_2, horizon= 60)

            # Guardar el archivo normalizado
            ruta_salida = os.path.join(directorio_salida, archivo)
            df_3.to_csv(ruta_salida, index=False)
            
        except Exception as e:
            print(f"Error procesando {archivo}: {str(e)}")
            continue

# %%
import os
import shutil
import pandas as pd

# Configuración
directorio = "./datos_normalizados"  # Cambia esto por tu directorio
directorio_salida = "./data_final_unknow_values_v3"  # Directorio para archivos normalizados

# Encontrar columnas comunes
data_augmentation_dataset_with_unknow_values(directorio, directorio_salida)
# Out:
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# ...
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
# /var/folders/gr/k4cy24rj4118z6hjbdmg2hdw0000gn/T/ipykernel_22800/809798560.py:173: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   features_df = features_df.fillna(method='ffill').fillna(method='bfill').fillna(0)
